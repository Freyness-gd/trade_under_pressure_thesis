# %% [markdown]
# # xLSTM, sLSTM, mLSTMs - with Checkpoints

# %% [markdown]
# ## Preparation

# %% [markdown]
# ### Import modules

# %%
# Cell 1: Mount & Navigate
from google.colab import drive
from torch.version import cuda

drive.mount('/content/drive')

# Go to correct folder
# %cd /content/drive/MyDrive/Colab\ Notebooks/thesis/LSTM_Train

# Verify structure
# !ls -la ../
# Should show: dataset/  thesis_utils/  LSTM_Train/

# !pip install loguru torchxlstm fastparquet

import sys
from pathlib import Path

# Add thesis_utils to path (parent dir)
sys.path.insert(0, '/content/drive/MyDrive/Colab\ Notebooks/thesis')

# Or simpler:
sys.path.insert(0, str(Path.cwd().parent))

# %%
# Prediction using LSTM, GRU-LSTM, xLSTM
import copy
import math
import os
from typing import List

import numpy as np
import pandas as pd

import torch
import torch.nn as nn
import torch.optim as optim
from torch.nn.utils import clip_grad_norm_
from torch.optim import Optimizer
from torch.optim.lr_scheduler import LRScheduler
from torch.utils.data import DataLoader, Dataset, Subset

from sklearn.model_selection import KFold, GroupShuffleSplit

import thesis_utils as tu

from torch.amp import GradScaler, autocast

# %%
CHKPT_DIR = "/content/checkpoints"
os.makedirs(CHKPT_DIR, exist_ok=True)

# %%
LOSS_DIR = "/content/drive/MyDrive/Colab Notebooks/thesis/XLSTM_Train/"
LOSS_LOG_PATH = os.path.join(LOSS_DIR, "train_loss.csv")

with open(LOSS_LOG_PATH, "w") as f:
  f.write("epoch,train_loss,val_loss\n")

# %%
def ckpt_path(serial, fold):
  return os.path.join(CHKPT_DIR, f"{serial}_fold{fold}.pt")

# %%
def safe_load_ckpt(path: str, map_location="cpu"):
  """Load a torch checkpoint, but delete it and return None if corrupted."""
  if not os.path.exists(path):
    return None

  try:
    return torch.load(path, map_location=map_location)
  except Exception as e:
    print(f"⚠️ Corrupted checkpoint detected: {path}")
    print(f"   Error: {e}")
    # Delete immediately so it cannot be loaded again later
    try:
      os.remove(path)
      print("   Deleted corrupted checkpoint.")
    except Exception as del_e:
      print(f"   Could not delete checkpoint: {del_e}")
    return None

# %% [markdown]
# ### Configuration

# %%
# Model parameters
HORIZON = 1
BATCH_SIZE = 2048  # Increased to saturate GPU
EMBEDDING_SIZE = 256
NUM_EPOCHS = 100
HIDDEN_SIZE = 512
N_LAYERS = 3
DROPOUT = 0.05
XLSTM_TYPE = "X"
N_LAGS = 5

# Train parameters
TARGET = "EXPORT_centered"
FEATURES = [
  "contig", "comlang_off", "colony", "smctry",
]
N_SPLITS = 8
PATIENCE = 10
LEARNING_RATE = 1e-5
WEIGHT_DECAY = 1e-3
RANDOM_SEED = 16
SUBSAMPLE_ENABLED = False
N_DYADS = 10
XLSTM_LAYERS = "sm"

SANCTION_COLS = ["arms", "military", "trade", "travel", "other", "financial"]

# Torch config
torch.manual_seed(RANDOM_SEED)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# ----------------------------
# Colab / L4 performance knobs
# ----------------------------
if device.type == "cuda":
  print("GPU:", torch.cuda.get_device_name(0))
  print("CUDA:", torch.version.cuda, "| PyTorch:", torch.__version__)
  # !nvidia-smi -L

  # cuDNN autotuner (best when shapes are stable, typical in training)
  torch.backends.cudnn.benchmark = True

  # Better GEMM kernels on Ampere+ (L4 is Ada)
  torch.set_float32_matmul_precision("high")

  # Reduce allocator fragmentation for long runs
  os.environ.setdefault("PYTORCH_CUDA_ALLOC_CONF", "expandable_segments:True")

# Mixed precision (L4 supports bf16 well)
USE_AMP = True
AMP_DTYPE = torch.bfloat16 if (
    device.type == "cuda" and getattr(torch.cuda, "is_bf16_supported", lambda: False)()) else torch.float16

# torch.compile can improve throughput (PyTorch 2.0+)
USE_TORCH_COMPILE = True
COMPILE_MODE = "max-autotune"  # alternatives: "reduce-overhead", "default"

# GradScaler is needed for fp16; for bf16 it should be disabled
USE_GRAD_SCALER = (device.type == "cuda" and USE_AMP and AMP_DTYPE == torch.float16)

print("Using device:", device)
if torch.cuda.is_available():
  print(torch.cuda.get_device_name(0))
  # Enable TF32 for faster computing on Ampere+ GPUs
  torch.backends.cuda.matmul.allow_tf32 = True
  torch.backends.cudnn.allow_tf32 = True

dyads_case_study = [
  # "USA_CHN", "CHN_USA",
  # "USA_CAN", "CAN_USA",
  # "DEU_CHN", "CHN_DEU",
  # "USA_DEU", "DEU_USA",
  # "USA_MEX", "MEX_USA",
  # "AUS_CHN", "CHN_AUS",
  # "USA_JPN", "JPN_USA",
  # "DEU_JPN", "JPN_DEU",
  # "USA_AUS", "AUS_USA",
  # "DEU_RUS", "RUS_DEU",
]

# %%
# Save config
SAVE_ENABLED = False
layers_string = f"({XLSTM_LAYERS})"
SERIAL_NUMBER = (
  f"{XLSTM_TYPE}LSTM"
  f"{layers_string if XLSTM_TYPE == 'X' else ''}"
  f"-{LEARNING_RATE}lr-{DROPOUT}d-{HIDDEN_SIZE}hs-{WEIGHT_DECAY}wd-{BATCH_SIZE}bs-{N_LAYERS}layers-{EMBEDDING_SIZE}es-kfolds{N_SPLITS}-hp"
)
SERIAL_NUMBER = SERIAL_NUMBER.replace(".", "_")
PATH_TO_FOLDER = ""

# %% [markdown]
# ### Load Data

# %%
from pandas import DataFrame

processed = pd.read_parquet(path="../dataset/processed.parquet", engine="fastparquet")
df: DataFrame = processed.copy(deep=True)

# %% [markdown]
# ### Sort, shift and compute data

# %%
# Sort data by Report + Partner + Year
df["dyad_id"] = df["ISO3_reporter"] + "_" + df["ISO3_partner"]
df = df.sort_values(by=["dyad_id", "Year"], ignore_index=True)

# %%
# Remove case study dyad_pairs
mask_keep = ~np.isin(df["dyad_id"], dyads_case_study)
df = df.loc[mask_keep].reset_index(drop=True)

# %%
# Sanity check case study pairs
has_overlap = df["dyad_id"].isin(dyads_case_study).any()

if has_overlap:
  print("⚠️ Some case study dyads are present in the DataFrame.")
else:
  print("✅ No case study dyads found in the DataFrame.")
# Out:
# ✅ No case study dyads found in the DataFrame.

# %%
if SUBSAMPLE_ENABLED:
  dyad_subsample = pd.Series(df["dyad_id"].unique()).sample(n=N_DYADS, random_state=RANDOM_SEED, replace=False)
  df = df[df["dyad_id"].isin(dyad_subsample)]

print(f"Unique dyads: {df["dyad_id"].nunique()}")
# Out:
# Unique dyads: 33672

# %%
df["sanction"] = (df[SANCTION_COLS]
                  .sum(axis=1)).astype(int)

# %% [markdown]
# ### Coerce numerical values and convert dyad_id to categorical

# %%
num_cols = ["distw", "GDP_reporter", "GDP_partner", "sanction", "contig",
            "comlang_off", "colony", "smctry", "Year", ]
df[num_cols] = df[num_cols].apply(pd.to_numeric, errors="coerce").astype(float)
df = df.dropna(subset=num_cols)

# %%
df["Year"] = df["Year"].astype(int)
for col in ["dyad_id"]:
  df[col] = pd.Categorical(df[col], categories=sorted(df[col].unique()))

# %%
# Save EXPORT std and median to undo centering
EXPORT_STD = df["EXPORT"].std()
EXPORT_MEDIAN = df["EXPORT"].median()

# %% [markdown]
# ### Center data

# %%
center_columns = ["distw", "GDP_reporter", "GDP_partner", "EXPORT"]
for col in center_columns:
  median = df[col].median()
  std_df = df[col].std()
  df[col + "_centered"] = (df[col] - median) / std_df
FEATURES += ["distw_centered"]

# %%
lag_cols = ["GDP_reporter_centered", "GDP_partner_centered", "sanction"]
for col in lag_cols:
  for index in range(1, N_LAGS + 1):
    df[f"{col}_lag{index}"] = df.groupby("dyad_id", observed=True)[col].shift(index)

# %%
df = df.dropna()

# %%
FEATURES += [f"{c}_lag{index}" for c in lag_cols for index in range(1, N_LAGS + 1)]

# %% [markdown]
# ## Split data

# %%
# Embeddings
dyad_to_idx = { dyad: i for i, dyad in enumerate(df["dyad_id"].cat.categories) }
df["dyad_idx"] = df["dyad_id"].map(dyad_to_idx).astype(int)

# %%
# Split into Train, Validation and Test sets
gss = GroupShuffleSplit(n_splits=1, test_size=0.2, random_state=RANDOM_SEED)

train_idx, test_idx = next(gss.split(df, groups=df["dyad_id"]))
test_df = df.iloc[test_idx]
train_df = df.iloc[train_idx]

train_idx, val_idx = next(gss.split(train_df, groups=train_df["dyad_id"]))
val_df = train_df.iloc[val_idx]
train_df = train_df.iloc[train_idx]

# %%
train_df.loc[:, FEATURES] = train_df.loc[:, FEATURES].astype(
  "float32",
  copy=False
)

# %% [markdown]
# # Train

# %% [markdown]
# ## Define Fold and Epoch steps
# _For reusability_

# %%
# Create KFold object
kf = KFold(n_splits=N_SPLITS, shuffle=True, random_state=RANDOM_SEED)

# %%
def epoch_step(
    model: nn.Module,
    optimizer: Optimizer,
    criterion: nn.Module,
    scheduler: LRScheduler,
    train_loader: DataLoader,
    val_loader: DataLoader,
    device: any,
    scaler: torch.amp.GradScaler,
    epoch: int,
) -> float:
  # =========================
  # TRAIN
  # =========================
  model.train()
  train_loss_sum = 0.0
  train_count = 0

  for X, y, di in train_loader:
    X, y, di = map(lambda t: t.to(device, non_blocking=True), (X, y, di))

    optimizer.zero_grad(set_to_none=True)

    with autocast("cuda", dtype=torch.bfloat16):
      y_pred = model(X, di)
      if not torch.isfinite(y_pred).all():
        print("NaN/Inf in y_pred — stopping fold")
        return float("inf")

      loss = criterion(y_pred, y)

    if not torch.isfinite(loss):
      print("NaN/Inf loss — stopping fold")
      return float("inf")

    scaler.scale(loss).backward()
    scaler.unscale_(optimizer)
    clip_grad_norm_(model.parameters(), 0.3)

    scaler.step(optimizer)
    scaler.update()
    scheduler.step()

    train_loss_sum += loss.item()
    train_count += 1

  train_loss = train_loss_sum / train_count

  # =========================
  # VALIDATION
  # =========================
  model.eval()
  val_loss_sum = 0.0
  val_count = 0

  with torch.no_grad():
    for X, y, di in val_loader:
      X, y, di = map(lambda t: t.to(device, non_blocking=True), (X, y, di))
      with autocast("cuda", dtype=torch.bfloat16):
        preds = model(X, di)
        val_loss_sum += criterion(preds, y).item()
        val_count += 1

  val_rmse = math.sqrt(val_loss_sum / val_count)

  with open(LOSS_LOG_PATH, "a") as f:
    f.write(f"{epoch},{train_loss},{val_rmse}\n")

  return val_rmse

# %%
def _make_loader(subset, *, batch_size: int, shuffle: bool, n_workers: int) -> DataLoader:
  """Colab-friendly DataLoader with aggressive prefetch + pinned memory."""
  kwargs = dict(
    batch_size=batch_size,
    shuffle=shuffle,
    num_workers=n_workers,
    pin_memory=True,
    persistent_workers=(n_workers > 0),
  )

  # Only valid when num_workers > 0
  if n_workers > 0:
    kwargs["prefetch_factor"] = 4

  return DataLoader(subset, **kwargs)

# %%
# Define fold step
def fold_step(
    fold: int,
    train_idx: List,
    val_idx: List,
    dataset: Dataset,
    batch_size: int,
    num_epochs: int,
    model: nn.Module,
    device: any,
    optimizer: Optimizer,
    criterion: nn.Module,
    serial: str,
):
  # Use all available cores
  n_workers = min(8, (os.cpu_count() or 2))

  train_loader = _make_loader(Subset(dataset, train_idx), batch_size=batch_size, shuffle=True, n_workers=n_workers)
  val_loader = _make_loader(Subset(dataset, val_idx), batch_size=batch_size, shuffle=False, n_workers=n_workers)

  scheduler = torch.optim.lr_scheduler.OneCycleLR(
    optimizer,
    max_lr=7e-4,
    epochs=NUM_EPOCHS,
    steps_per_epoch=len(train_loader),
    div_factor=25,
    final_div_factor=100,
    pct_start=0.3,
    anneal_strategy="cos",
    three_phase=False,
  )

  ckpt_file = ckpt_path(serial, fold)
  tmp_ckpt_file = ckpt_file + ".tmp"

  ckpt = safe_load_ckpt(ckpt_file, map_location=device)

  start_epoch = 0
  best_rmse = float("inf")
  best_state = copy.deepcopy(model.state_dict())
  scaler = GradScaler("cuda", enabled=USE_GRAD_SCALER)

  if ckpt is not None:
    print(f"🔄 Resuming from checkpoint: {ckpt_file}")

    model.load_state_dict(ckpt["model_state"])
    optimizer.load_state_dict(ckpt["optimizer_state"])
    scheduler.load_state_dict(ckpt["scheduler_state"])
    scaler.load_state_dict(ckpt["scaler_state"])

    start_epoch = ckpt["epoch"] + 1
    best_rmse = ckpt["best_rmse"]
    best_state = ckpt["best_state"]

  print(f"Start epoch train for fold {fold}")

  for epoch in range(start_epoch, num_epochs):
    val_rmse = epoch_step(
      model=model,
      optimizer=optimizer,
      criterion=criterion,
      scheduler=scheduler,
      train_loader=train_loader,
      val_loader=val_loader,
      device=device,
      scaler=scaler,
      epoch=epoch
    )

    print(f"Epoch {epoch + 1:02d}/{num_epochs} | val RMSE: {val_rmse:.4f}")

    if val_rmse < best_rmse - 1e-4:
      best_rmse = val_rmse
      best_state = copy.deepcopy(model.state_dict())

    # =========================
    # ATOMIC CHECKPOINT SAVE
    # =========================
    state = {
      "epoch": epoch,
      "model_state": model.state_dict(),
      "optimizer_state": optimizer.state_dict(),
      "scheduler_state": scheduler.state_dict(),
      "scaler_state": scaler.state_dict(),
      "best_rmse": best_rmse,
      "best_state": best_state,
    }

    torch.save(state, tmp_ckpt_file)
    os.replace(tmp_ckpt_file, ckpt_file)

  # =========================
  # FINAL EVALUATION
  # =========================
  model.load_state_dict(best_state)
  model.eval()

  preds_centered, truth_centered = [], []

  with torch.inference_mode():
    for X, y, di in val_loader:
      X, di = map(lambda t: t.to(device, non_blocking=True), (X, di))

      with autocast("cuda", enabled=(getattr(device, "type", "cpu") == "cuda" and USE_AMP)):
        out = model(X, di)

        preds_centered.append(out.float().cpu())
        truth_centered.append(y)

  preds_centered = torch.cat(preds_centered).numpy()
  truth_centered = torch.cat(truth_centered).numpy()

  # Convert back to raw scale
  preds_raw = preds_centered * EXPORT_STD + EXPORT_MEDIAN
  truth_raw = truth_centered * EXPORT_STD + EXPORT_MEDIAN

  rmse_centered = tu.rmse(truth_centered, preds_centered)
  mae_centered = tu.mae(truth_centered, preds_centered)
  rmae_centered = tu.rmae(truth_centered, preds_centered)
  pseudo_r2_centered = tu.pseudo_r2(truth_centered, preds_centered)

  print(
    f"Fold {fold} CENTERED  RMSE {rmse_centered:.4f} | "
    f"MAE {mae_centered:.4f} | R² {pseudo_r2_centered:.4f} | "
    f"RMAE {rmae_centered:.4f}"
  )

  rmse_raw = tu.rmse(truth_raw, preds_raw)
  mae_raw = tu.mae(truth_raw, preds_raw)
  rmae_raw = tu.rmae(truth_raw, preds_raw)
  pseudo_r2_raw = tu.pseudo_r2(truth_raw, preds_raw)

  print(
    f"Fold {fold} RAW  RMSE {rmse_raw:.4f} | "
    f"MAE {mae_raw:.4f} | R² {pseudo_r2_raw:.4f} | "
    f"RMAE {rmae_raw:.4f}"
  )

  return (
    { "RMSE": rmse_centered, "MAE": mae_centered, "R2": pseudo_r2_centered, "RMAE": rmae_centered },
    { "RMSE": rmse_raw, "MAE": mae_raw, "R2": pseudo_r2_raw, "RMAE": rmae_raw },
    copy.deepcopy(best_state),
  )

# %% [markdown]
# ## Train Raw dataset

# %% [markdown]
# ### Split dataset

# %%
# Convert df_scaled to pytorch Tensor
dataset, dyad_to_idx = tu.make_panel_datasets_dyad(
  data=df,
  features=FEATURES,
  target=TARGET,
  horizon=HORIZON,
)

# %%
# Create DataLoaders for the 3 sets
n_workers = min(8, (os.cpu_count() or 2))

train_kwargs = dict(
  batch_size=BATCH_SIZE,
  shuffle=True,
  num_workers=n_workers,
  persistent_workers=(n_workers > 0),
  pin_memory=True,
)
val_kwargs = dict(
  batch_size=BATCH_SIZE,
  shuffle=False,
  num_workers=n_workers,
  persistent_workers=(n_workers > 0),
  pin_memory=True,
)
test_kwargs = dict(
  batch_size=BATCH_SIZE,
  shuffle=False,
  num_workers=n_workers,
  persistent_workers=(n_workers > 0),
  pin_memory=True,
)

if n_workers > 0:
  train_kwargs["prefetch_factor"] = 4
  val_kwargs["prefetch_factor"] = 4
  test_kwargs["prefetch_factor"] = 4

train_loader = DataLoader(Subset(dataset, train_idx), **train_kwargs)
val_loader = DataLoader(Subset(dataset, val_idx), **val_kwargs)
test_loader = DataLoader(Subset(dataset, test_idx), **test_kwargs)

# %% [markdown]
# ### Train model

# %%
# Save best train iteration
best_fold_state = None
best_fold_rmse = float("inf")

metrics_per_fold = {
  "RMSE": [],
  "MAE": [],
  "R2": [],
  "RMAE": [],
}

metrics_per_fold_raw = {
  "RMSE": [],
  "MAE": [],
  "R2": [],
  "RMAE": [],
}

# %%
for fold, (train_idx, val_idx) in enumerate(kf.split(np.arange(len(dataset))), 1):

  ckpt_file = ckpt_path(SERIAL_NUMBER, fold)
  ckpt = safe_load_ckpt(ckpt_file, map_location="cpu")

  if ckpt is not None and ckpt.get("epoch", -1) >= NUM_EPOCHS - 1:
    print(f"✅ Fold {fold} already completed — skipping.")
    continue

  print(f"=== FOLD {fold}/{N_SPLITS} ===")

  model = tu.DyadXLSTM(
    n_features=len(FEATURES),
    n_dyads=len(dyad_to_idx),
    embed_dim=EMBEDDING_SIZE,
    hidden_size=HIDDEN_SIZE,
    dropout=DROPOUT,
    horizon=HORIZON,
    type=XLSTM_TYPE,
    layers=XLSTM_LAYERS,
    n_layers=N_LAYERS,
  ).to(device=device)

  # JIT Compile the model for speedup (requires PyTorch 2.0+)
  if USE_TORCH_COMPILE and hasattr(torch, "compile") and device.type == "cuda":
    try:
      model = torch.compile(model, mode=COMPILE_MODE)
      print(f"Model compiled with torch.compile(mode={COMPILE_MODE!r})")
    except Exception as e:
      print(f"Could not compile model: {e}")

  criterion = nn.SmoothL1Loss(beta=0.5)

  adamw_kwargs = dict(lr=LEARNING_RATE, weight_decay=WEIGHT_DECAY, betas=(0.9, 0.95), eps=1e-8)
  if device.type == "cuda":
    try:
      optimizer = optim.AdamW(model.parameters(), **adamw_kwargs, fused=True)
      print("Using fused AdamW")
    except TypeError:
      optimizer = optim.AdamW(model.parameters(), **adamw_kwargs)
  else:
    optimizer = optim.AdamW(model.parameters(), **adamw_kwargs)

  fold_metrics, fold_metrics_raw, best_state = fold_step(fold=fold,
                                                         train_idx=train_idx,
                                                         val_idx=val_idx,
                                                         dataset=dataset,
                                                         batch_size=BATCH_SIZE,
                                                         num_epochs=NUM_EPOCHS,
                                                         model=model,
                                                         device=device,
                                                         optimizer=optimizer,
                                                         criterion=criterion,
                                                         serial=SERIAL_NUMBER)

  if fold_metrics["RMSE"] < best_fold_rmse:
    best_fold_rmse = fold_metrics["RMSE"]
    best_fold_state = copy.deepcopy(best_state)

  for k, v in fold_metrics.items():
    metrics_per_fold[k].append(v)

  for k, v in fold_metrics_raw.items():
    metrics_per_fold_raw[k].append(v)
# Out:
# === FOLD 1/8 ===
# Model compiled with torch.compile(mode='max-autotune')
# Using fused AdamW
# Start epoch train for fold 1
# W1229 10:30:07.500000 159865 torch/_inductor/utils.py:1558] [0/0] Not enough SMs to use max_autotune_gemm mode
# Autotune Choices Stats:
# {"num_choices": 2, "num_triton_choices": 0, "best_kernel": "bias_addmm", "best_time": 0.04608000069856644}
# AUTOTUNE addmm(2048x682, 2048x512, 512x682)
# strides: [0, 1], [512, 1], [1, 512]
# dtypes: torch.bfloat16, torch.bfloat16, torch.bfloat16
#   bias_addmm 0.0461 ms 100.0%
#   addmm 0.0635 ms 72.6%
# SingleProcess AUTOTUNE benchmarking takes 0.0927 seconds and 0.0004 seconds precompiling for 2 choices
# Autotune Choices Stats:
# {"num_choices": 2, "num_triton_choices": 0, "best_kernel": "bias_addmm", "best_time": 0.05632000043988228}
# AUTOTUNE addmm(2048x512, 2048x552, 552x512)
# strides: [0, 1], [552, 1], [1, 552]
# dtypes: torch.bfloat16, torch.bfloat16, torch.bfloat16
#   bias_addmm 0.0563 ms 100.0%
#   addmm 0.0717 ms 78.6%
# SingleProcess AUTOTUNE benchmarking takes 0.0928 seconds and 0.0002 seconds precompiling for 2 choices
# Autotune Choices Stats:
# {"num_choices": 2, "num_triton_choices": 0, "best_kernel": "bias_addmm", "best_time": 0.03993599861860275}
# AUTOTUNE addmm(2048x512, 2048x276, 276x512)
# strides: [0, 1], [276, 1], [1, 276]
# dtypes: torch.bfloat16, torch.bfloat16, torch.bfloat16
#   bias_addmm 0.0399 ms 100.0%
#   addmm 0.0512 ms 78.0%
# SingleProcess AUTOTUNE benchmarking takes 0.0903 seconds and 0.0002 seconds precompiling for 2 choices
# Autotune Choices Stats:
# {"num_choices": 2, "num_triton_choices": 0, "best_kernel": "bias_addmm", "best_time": 0.03276799991726875}
# AUTOTUNE addmm(2048x552, 2048x276, 276x552)
# strides: [0, 1], [276, 1], [1, 276]
# dtypes: torch.bfloat16, torch.bfloat16, torch.bfloat16
#   bias_addmm 0.0328 ms 100.0%
#   addmm 0.0481 ms 68.1%
# SingleProcess AUTOTUNE benchmarking takes 0.0894 seconds and 0.0002 seconds precompiling for 2 choices
# Autotune Choices Stats:
# {"num_choices": 2, "num_triton_choices": 0, "best_kernel": "bias_addmm", "best_time": 0.03379200026392937}
# AUTOTUNE addmm(1224x682, 1224x512, 512x682)
# strides: [0, 1], [512, 1], [1, 512]
# dtypes: torch.bfloat16, torch.bfloat16, torch.bfloat16
#   bias_addmm 0.0338 ms 100.0%
#   addmm 0.0440 ms 76.7%
# SingleProcess AUTOTUNE benchmarking takes 0.0911 seconds and 0.0003 seconds precompiling for 2 choices
# Autotune Choices Stats:
# {"num_choices": 2, "num_triton_choices": 0, "best_kernel": "bias_addmm", "best_time": 0.04710400104522705}
# AUTOTUNE addmm(1224x512, 1224x552, 552x512)
# strides: [0, 1], [552, 1], [1, 552]
# dtypes: torch.bfloat16, torch.bfloat16, torch.bfloat16
#   bias_addmm 0.0471 ms 100.0%
#   addmm 0.0522 ms 90.2%
# SingleProcess AUTOTUNE benchmarking takes 0.0915 seconds and 0.0002 seconds precompiling for 2 choices
# Autotune Choices Stats:
# {"num_choices": 2, "num_triton_choices": 0, "best_kernel": "bias_addmm", "best_time": 0.026623999699950218}
# AUTOTUNE addmm(1224x512, 1224x276, 276x512)
# strides: [0, 1], [276, 1], [1, 276]
# dtypes: torch.bfloat16, torch.bfloat16, torch.bfloat16
#   bias_addmm 0.0266 ms 100.0%
#   addmm 0.0348 ms 76.5%
# SingleProcess AUTOTUNE benchmarking takes 0.0886 seconds and 0.0002 seconds precompiling for 2 choices
# Autotune Choices Stats:
# {"num_choices": 2, "num_triton_choices": 0, "best_kernel": "bias_addmm", "best_time": 0.023552000522613525}
# AUTOTUNE addmm(1224x552, 1224x276, 276x552)
# strides: [0, 1], [276, 1], [1, 276]
# dtypes: torch.bfloat16, torch.bfloat16, torch.bfloat16
#   bias_addmm 0.0236 ms 100.0%
#   addmm 0.0297 ms 79.3%
# SingleProcess AUTOTUNE benchmarking takes 0.0883 seconds and 0.0002 seconds precompiling for 2 choices
# Epoch 01/100 | val RMSE: 0.2464
# Epoch 02/100 | val RMSE: 0.2075
# Epoch 03/100 | val RMSE: 0.1815
# Epoch 04/100 | val RMSE: 0.1694
# Epoch 05/100 | val RMSE: 0.1640
# Epoch 06/100 | val RMSE: 0.1607
# Epoch 07/100 | val RMSE: 0.1567
# Epoch 08/100 | val RMSE: 0.1662
# Epoch 09/100 | val RMSE: 0.1538
# Epoch 10/100 | val RMSE: 0.1522
# Epoch 11/100 | val RMSE: 0.1577
# Epoch 12/100 | val RMSE: 0.1475
# Epoch 13/100 | val RMSE: 0.1523
# Epoch 14/100 | val RMSE: 0.1486
# Epoch 15/100 | val RMSE: 0.1533
# Epoch 16/100 | val RMSE: 0.1494
# Epoch 17/100 | val RMSE: 0.1493
# Epoch 18/100 | val RMSE: 0.1466
# Epoch 19/100 | val RMSE: 0.1489
# Epoch 20/100 | val RMSE: 0.1490
# Epoch 21/100 | val RMSE: 0.1508
# Epoch 22/100 | val RMSE: 0.1402
# Epoch 23/100 | val RMSE: 0.1439
# Epoch 24/100 | val RMSE: 0.1417
# Epoch 25/100 | val RMSE: 0.1418
# Epoch 26/100 | val RMSE: 0.1418
# Epoch 27/100 | val RMSE: 0.1384
# Epoch 28/100 | val RMSE: 0.1380
# Epoch 29/100 | val RMSE: 0.1366
# Epoch 30/100 | val RMSE: 0.1395
# Epoch 31/100 | val RMSE: 0.1404
# Epoch 32/100 | val RMSE: 0.1351
# Epoch 33/100 | val RMSE: 0.1348
# Epoch 34/100 | val RMSE: 0.1384
# Epoch 35/100 | val RMSE: 0.1368
# Epoch 36/100 | val RMSE: 0.1316
# Epoch 37/100 | val RMSE: 0.1351
# Epoch 38/100 | val RMSE: 0.1287
# Epoch 39/100 | val RMSE: 0.1462
# Epoch 40/100 | val RMSE: 0.1314
# Epoch 41/100 | val RMSE: 0.1330
# Epoch 42/100 | val RMSE: 0.1346
# Epoch 43/100 | val RMSE: 0.1331
# Epoch 44/100 | val RMSE: 0.1276
# Epoch 45/100 | val RMSE: 0.1288
# Epoch 46/100 | val RMSE: 0.1284
# Epoch 47/100 | val RMSE: 0.1350
# Epoch 48/100 | val RMSE: 0.1284
# Epoch 49/100 | val RMSE: 0.1340
# Epoch 50/100 | val RMSE: 0.1272
# Epoch 51/100 | val RMSE: 0.1271
# Epoch 52/100 | val RMSE: 0.1254
# Epoch 53/100 | val RMSE: 0.1296
# Epoch 54/100 | val RMSE: 0.1267
# Epoch 55/100 | val RMSE: 0.1284
# Epoch 56/100 | val RMSE: 0.1231
# Epoch 57/100 | val RMSE: 0.1212
# Epoch 58/100 | val RMSE: 0.1260
# Epoch 59/100 | val RMSE: 0.1245
# Epoch 60/100 | val RMSE: 0.1217
# Epoch 61/100 | val RMSE: 0.1260
# Epoch 62/100 | val RMSE: 0.1223
# Epoch 63/100 | val RMSE: 0.1212
# Epoch 64/100 | val RMSE: 0.1234
# Epoch 65/100 | val RMSE: 0.1194
# Epoch 66/100 | val RMSE: 0.1199
# Epoch 67/100 | val RMSE: 0.1268
# Epoch 68/100 | val RMSE: 0.1221
# Epoch 69/100 | val RMSE: 0.1215
# Epoch 70/100 | val RMSE: 0.1195
# Epoch 71/100 | val RMSE: 0.1214
# Epoch 72/100 | val RMSE: 0.1254
# Epoch 73/100 | val RMSE: 0.1223
# Epoch 74/100 | val RMSE: 0.1170
# Epoch 75/100 | val RMSE: 0.1156
# Epoch 76/100 | val RMSE: 0.1161
# Epoch 77/100 | val RMSE: 0.1177
# Epoch 78/100 | val RMSE: 0.1152
# Epoch 79/100 | val RMSE: 0.1188
# Epoch 80/100 | val RMSE: 0.1174
# Epoch 81/100 | val RMSE: 0.1162
# Epoch 82/100 | val RMSE: 0.1167
# Epoch 83/100 | val RMSE: 0.1149
# Epoch 84/100 | val RMSE: 0.1158
# Epoch 85/100 | val RMSE: 0.1185
# Epoch 86/100 | val RMSE: 0.1158
# Epoch 87/100 | val RMSE: 0.1160
# Epoch 88/100 | val RMSE: 0.1149
# Epoch 89/100 | val RMSE: 0.1152
# Epoch 90/100 | val RMSE: 0.1158
# Epoch 91/100 | val RMSE: 0.1161
# Epoch 92/100 | val RMSE: 0.1152
# Epoch 93/100 | val RMSE: 0.1158
# Epoch 94/100 | val RMSE: 0.1153
# Epoch 95/100 | val RMSE: 0.1155
# Epoch 96/100 | val RMSE: 0.1155
# Epoch 97/100 | val RMSE: 0.1153
# Epoch 98/100 | val RMSE: 0.1154
# Epoch 99/100 | val RMSE: 0.1153
# Epoch 100/100 | val RMSE: 0.1153
# Fold 1 CENTERED  RMSE 0.4986 | MAE 0.0285 | R² 0.8243 | RMAE 0.3438
# Fold 1 RAW  RMSE 2101826.9420 | MAE 119985.7615 | R² 0.8243 | RMAE 0.3438
# === FOLD 2/8 ===
# Model compiled with torch.compile(mode='max-autotune')
# Using fused AdamW
# Start epoch train for fold 2
# Epoch 01/100 | val RMSE: 0.2418
# Epoch 02/100 | val RMSE: 0.2004
# Epoch 03/100 | val RMSE: 0.1747
# Epoch 04/100 | val RMSE: 0.1649
# Epoch 05/100 | val RMSE: 0.1650
# Epoch 06/100 | val RMSE: 0.1594
# Epoch 07/100 | val RMSE: 0.1527
# Epoch 08/100 | val RMSE: 0.1589
# Epoch 09/100 | val RMSE: 0.1494
# Epoch 10/100 | val RMSE: 0.1555
# Epoch 11/100 | val RMSE: 0.1569
# Epoch 12/100 | val RMSE: 0.1541
# Epoch 13/100 | val RMSE: 0.1502
# Epoch 14/100 | val RMSE: 0.1498
# Epoch 15/100 | val RMSE: 0.1506
# Epoch 16/100 | val RMSE: 0.1481
# Epoch 17/100 | val RMSE: 0.1448
# Epoch 18/100 | val RMSE: 0.1452
# Epoch 19/100 | val RMSE: 0.1482
# Epoch 20/100 | val RMSE: 0.1454
# Epoch 21/100 | val RMSE: 0.1404
# Epoch 22/100 | val RMSE: 0.1434
# Epoch 23/100 | val RMSE: 0.1428
# Epoch 24/100 | val RMSE: 0.1433
# Epoch 25/100 | val RMSE: 0.1395
# Epoch 26/100 | val RMSE: 0.1423
# Epoch 27/100 | val RMSE: 0.1440
# Epoch 28/100 | val RMSE: 0.1372
# Epoch 29/100 | val RMSE: 0.1381
# Epoch 30/100 | val RMSE: 0.1330
# Epoch 31/100 | val RMSE: 0.1553
# Epoch 32/100 | val RMSE: 0.1384
# Epoch 33/100 | val RMSE: 0.1377
# Epoch 34/100 | val RMSE: 0.1313
# Epoch 35/100 | val RMSE: 0.1324
# Epoch 36/100 | val RMSE: 0.1327
# Epoch 37/100 | val RMSE: 0.1284
# Epoch 38/100 | val RMSE: 0.1282
# Epoch 39/100 | val RMSE: 0.1282
# Epoch 40/100 | val RMSE: 0.1302
# Epoch 41/100 | val RMSE: 0.1317
# Epoch 42/100 | val RMSE: 0.1232
# Epoch 43/100 | val RMSE: 0.1311
# Epoch 44/100 | val RMSE: 0.1260
# Epoch 45/100 | val RMSE: 0.1289
# Epoch 46/100 | val RMSE: 0.1230
# Epoch 47/100 | val RMSE: 0.1266
# Epoch 48/100 | val RMSE: 0.1232
# Epoch 49/100 | val RMSE: 0.1243
# Epoch 50/100 | val RMSE: 0.1273
# Epoch 51/100 | val RMSE: 0.1267
# Epoch 52/100 | val RMSE: 0.1250
# Epoch 53/100 | val RMSE: 0.1221
# Epoch 54/100 | val RMSE: 0.1221
# Epoch 55/100 | val RMSE: 0.1209
# Epoch 56/100 | val RMSE: 0.1198
# Epoch 57/100 | val RMSE: 0.1263
# Epoch 58/100 | val RMSE: 0.1230
# Epoch 59/100 | val RMSE: 0.1229
# Epoch 60/100 | val RMSE: 0.1229
# Epoch 61/100 | val RMSE: 0.1200
# Epoch 62/100 | val RMSE: 0.1227
# Epoch 63/100 | val RMSE: 0.1214
# Epoch 64/100 | val RMSE: 0.1189
# Epoch 65/100 | val RMSE: 0.1198
# Epoch 66/100 | val RMSE: 0.1190
# Epoch 67/100 | val RMSE: 0.1190
# Epoch 68/100 | val RMSE: 0.1211
# Epoch 69/100 | val RMSE: 0.1216
# Epoch 70/100 | val RMSE: 0.1183
# Epoch 71/100 | val RMSE: 0.1152
# Epoch 72/100 | val RMSE: 0.1174
# Epoch 73/100 | val RMSE: 0.1163
# Epoch 74/100 | val RMSE: 0.1139
# Epoch 75/100 | val RMSE: 0.1137
# Epoch 76/100 | val RMSE: 0.1153
# Epoch 77/100 | val RMSE: 0.1145
# Epoch 78/100 | val RMSE: 0.1140
# Epoch 79/100 | val RMSE: 0.1137
# Epoch 80/100 | val RMSE: 0.1143
# Epoch 81/100 | val RMSE: 0.1143
# Epoch 82/100 | val RMSE: 0.1130
# Epoch 83/100 | val RMSE: 0.1132
# Epoch 84/100 | val RMSE: 0.1139
# Epoch 85/100 | val RMSE: 0.1117
# Epoch 86/100 | val RMSE: 0.1120
# Epoch 87/100 | val RMSE: 0.1115
# Epoch 88/100 | val RMSE: 0.1121
# Epoch 89/100 | val RMSE: 0.1119
# Epoch 90/100 | val RMSE: 0.1118
# Epoch 91/100 | val RMSE: 0.1135
# Epoch 92/100 | val RMSE: 0.1140
# Epoch 93/100 | val RMSE: 0.1141
# Epoch 94/100 | val RMSE: 0.1142
# Epoch 95/100 | val RMSE: 0.1155
# Epoch 96/100 | val RMSE: 0.1156
# Epoch 97/100 | val RMSE: 0.1161
# Epoch 98/100 | val RMSE: 0.1160
# Epoch 99/100 | val RMSE: 0.1158
# Epoch 100/100 | val RMSE: 0.1158
# Fold 2 CENTERED  RMSE 0.4319 | MAE 0.0279 | R² 0.8501 | RMAE 0.3464
# Fold 2 RAW  RMSE 1820589.8963 | MAE 117699.8788 | R² 0.8501 | RMAE 0.3464
# === FOLD 3/8 ===
# Model compiled with torch.compile(mode='max-autotune')
# Using fused AdamW
# Start epoch train for fold 3
# Epoch 01/100 | val RMSE: 0.2413
# Epoch 02/100 | val RMSE: 0.2025
# Epoch 03/100 | val RMSE: 0.1691
# Epoch 04/100 | val RMSE: 0.1584
# Epoch 05/100 | val RMSE: 0.1544
# Epoch 06/100 | val RMSE: 0.1494
# Epoch 07/100 | val RMSE: 0.1466
# Epoch 08/100 | val RMSE: 0.1490
# Epoch 09/100 | val RMSE: 0.1475
# Epoch 10/100 | val RMSE: 0.1451
# Epoch 11/100 | val RMSE: 0.1463
# Epoch 12/100 | val RMSE: 0.1497
# Epoch 13/100 | val RMSE: 0.1413
# Epoch 14/100 | val RMSE: 0.1378
# Epoch 15/100 | val RMSE: 0.1434
# Epoch 16/100 | val RMSE: 0.1455
# Epoch 17/100 | val RMSE: 0.1427
# Epoch 18/100 | val RMSE: 0.1359
# Epoch 19/100 | val RMSE: 0.1391
# Epoch 20/100 | val RMSE: 0.1318
# Epoch 21/100 | val RMSE: 0.1409
# Epoch 22/100 | val RMSE: 0.1377
# Epoch 23/100 | val RMSE: 0.1376
# Epoch 24/100 | val RMSE: 0.1347
# Epoch 25/100 | val RMSE: 0.1328
# Epoch 26/100 | val RMSE: 0.1327
# Epoch 27/100 | val RMSE: 0.1333
# Epoch 28/100 | val RMSE: 0.1333
# Epoch 29/100 | val RMSE: 0.1286
# Epoch 30/100 | val RMSE: 0.1314
# Epoch 31/100 | val RMSE: 0.1312
# Epoch 32/100 | val RMSE: 0.1248
# Epoch 33/100 | val RMSE: 0.1222
# Epoch 34/100 | val RMSE: 0.1240
# Epoch 35/100 | val RMSE: 0.1261
# Epoch 36/100 | val RMSE: 0.1208
# Epoch 37/100 | val RMSE: 0.1228
# Epoch 38/100 | val RMSE: 0.1258
# Epoch 39/100 | val RMSE: 0.1201
# Epoch 40/100 | val RMSE: 0.1198
# Epoch 41/100 | val RMSE: 0.1273
# Epoch 42/100 | val RMSE: 0.1157
# Epoch 43/100 | val RMSE: 0.1189
# Epoch 44/100 | val RMSE: 0.1177
# Epoch 45/100 | val RMSE: 0.1167
# Epoch 46/100 | val RMSE: 0.1172
# Epoch 47/100 | val RMSE: 0.1164
# Epoch 48/100 | val RMSE: 0.1162
# Epoch 49/100 | val RMSE: 0.1252
# Epoch 50/100 | val RMSE: 0.1133
# Epoch 51/100 | val RMSE: 0.1135
# Epoch 52/100 | val RMSE: 0.1159
# Epoch 53/100 | val RMSE: 0.1169
# Epoch 54/100 | val RMSE: 0.1151
# Epoch 55/100 | val RMSE: 0.1170
# Epoch 56/100 | val RMSE: 0.1174
# Epoch 57/100 | val RMSE: 0.1129
# Epoch 58/100 | val RMSE: 0.1168
# Epoch 59/100 | val RMSE: 0.1129
# Epoch 60/100 | val RMSE: 0.1124
# Epoch 61/100 | val RMSE: 0.1112
# Epoch 62/100 | val RMSE: 0.1137
# Epoch 63/100 | val RMSE: 0.1112
# Epoch 64/100 | val RMSE: 0.1138
# Epoch 65/100 | val RMSE: 0.1117
# Epoch 66/100 | val RMSE: 0.1096
# Epoch 67/100 | val RMSE: 0.1110
# Epoch 68/100 | val RMSE: 0.1111
# Epoch 69/100 | val RMSE: 0.1113
# Epoch 70/100 | val RMSE: 0.1100
# Epoch 71/100 | val RMSE: 0.1089
# Epoch 72/100 | val RMSE: 0.1077
# Epoch 73/100 | val RMSE: 0.1059
# Epoch 74/100 | val RMSE: 0.1046
# Epoch 75/100 | val RMSE: 0.1062
# Epoch 76/100 | val RMSE: 0.1064
# Epoch 77/100 | val RMSE: 0.1062
# Epoch 78/100 | val RMSE: 0.1041
# Epoch 79/100 | val RMSE: 0.1041
# Epoch 80/100 | val RMSE: 0.1050
# Epoch 81/100 | val RMSE: 0.1025
# Epoch 82/100 | val RMSE: 0.1030
# Epoch 83/100 | val RMSE: 0.1041
# Epoch 84/100 | val RMSE: 0.1046
# Epoch 85/100 | val RMSE: 0.1041
# Epoch 86/100 | val RMSE: 0.1029
# Epoch 87/100 | val RMSE: 0.1034
# Epoch 88/100 | val RMSE: 0.1025
# Epoch 89/100 | val RMSE: 0.1034
# Epoch 90/100 | val RMSE: 0.1030
# Epoch 91/100 | val RMSE: 0.1024
# Epoch 92/100 | val RMSE: 0.1024
# Epoch 93/100 | val RMSE: 0.1021
# Epoch 94/100 | val RMSE: 0.1021
# Epoch 95/100 | val RMSE: 0.1021
# Epoch 96/100 | val RMSE: 0.1022
# Epoch 97/100 | val RMSE: 0.1022
# Epoch 98/100 | val RMSE: 0.1021
# Epoch 99/100 | val RMSE: 0.1021
# Epoch 100/100 | val RMSE: 0.1021
# Fold 3 CENTERED  RMSE 0.2712 | MAE 0.0232 | R² 0.9413 | RMAE 0.2839
# Fold 3 RAW  RMSE 1143354.6160 | MAE 97744.1786 | R² 0.9413 | RMAE 0.2839
# === FOLD 4/8 ===
# Model compiled with torch.compile(mode='max-autotune')
# Using fused AdamW
# Start epoch train for fold 4
# Epoch 01/100 | val RMSE: 0.2301
# Epoch 02/100 | val RMSE: 0.1914
# Epoch 03/100 | val RMSE: 0.1620
# Epoch 04/100 | val RMSE: 0.1514
# Epoch 05/100 | val RMSE: 0.1468
# Epoch 06/100 | val RMSE: 0.1462
# Epoch 07/100 | val RMSE: 0.1436
# Epoch 08/100 | val RMSE: 0.1403
# Epoch 09/100 | val RMSE: 0.1382
# Epoch 10/100 | val RMSE: 0.1405
# Epoch 11/100 | val RMSE: 0.1446
# Epoch 12/100 | val RMSE: 0.1397
# Epoch 13/100 | val RMSE: 0.1362
# Epoch 14/100 | val RMSE: 0.1411
# Epoch 15/100 | val RMSE: 0.1368
# Epoch 16/100 | val RMSE: 0.1331
# Epoch 17/100 | val RMSE: 0.1372
# Epoch 18/100 | val RMSE: 0.1372
# Epoch 19/100 | val RMSE: 0.1328
# Epoch 20/100 | val RMSE: 0.1390
# Epoch 21/100 | val RMSE: 0.1328
# Epoch 22/100 | val RMSE: 0.1284
# Epoch 23/100 | val RMSE: 0.1330
# Epoch 24/100 | val RMSE: 0.1362
# Epoch 25/100 | val RMSE: 0.1230
# Epoch 26/100 | val RMSE: 0.1237
# Epoch 27/100 | val RMSE: 0.1223
# Epoch 28/100 | val RMSE: 0.1208
# Epoch 29/100 | val RMSE: 0.1207
# Epoch 30/100 | val RMSE: 0.1214
# Epoch 31/100 | val RMSE: 0.1184
# Epoch 32/100 | val RMSE: 0.1174
# Epoch 33/100 | val RMSE: 0.1199
# Epoch 34/100 | val RMSE: 0.1227
# Epoch 35/100 | val RMSE: 0.1191
# Epoch 36/100 | val RMSE: 0.1182
# Epoch 37/100 | val RMSE: 0.1159
# Epoch 38/100 | val RMSE: 0.1166
# Epoch 39/100 | val RMSE: 0.1153
# Epoch 40/100 | val RMSE: 0.1141
# Epoch 41/100 | val RMSE: 0.1135
# Epoch 42/100 | val RMSE: 0.1134
# Epoch 43/100 | val RMSE: 0.1135
# Epoch 44/100 | val RMSE: 0.1128
# Epoch 45/100 | val RMSE: 0.1135
# Epoch 46/100 | val RMSE: 0.1138
# Epoch 47/100 | val RMSE: 0.1153
# Epoch 48/100 | val RMSE: 0.1128
# Epoch 49/100 | val RMSE: 0.1142
# Epoch 50/100 | val RMSE: 0.1094
# Epoch 51/100 | val RMSE: 0.1143
# Epoch 52/100 | val RMSE: 0.1108
# Epoch 53/100 | val RMSE: 0.1090
# Epoch 54/100 | val RMSE: 0.1078
# Epoch 55/100 | val RMSE: 0.1098
# Epoch 56/100 | val RMSE: 0.1102
# Epoch 57/100 | val RMSE: 0.1089
# Epoch 58/100 | val RMSE: 0.1057
# Epoch 59/100 | val RMSE: 0.1075
# Epoch 60/100 | val RMSE: 0.1047
# Epoch 61/100 | val RMSE: 0.1047
# Epoch 62/100 | val RMSE: 0.1071
# Epoch 63/100 | val RMSE: 0.1052
# Epoch 64/100 | val RMSE: 0.1040
# Epoch 65/100 | val RMSE: 0.1036
# Epoch 66/100 | val RMSE: 0.1019
# Epoch 67/100 | val RMSE: 0.1026
# Epoch 68/100 | val RMSE: 0.1017
# Epoch 69/100 | val RMSE: 0.1030
# Epoch 70/100 | val RMSE: 0.1013
# Epoch 71/100 | val RMSE: 0.1010
# Epoch 72/100 | val RMSE: 0.1011
# Epoch 73/100 | val RMSE: 0.0997
# Epoch 74/100 | val RMSE: 0.0992
# Epoch 75/100 | val RMSE: 0.0989
# Epoch 76/100 | val RMSE: 0.0992
# Epoch 77/100 | val RMSE: 0.0995
# Epoch 78/100 | val RMSE: 0.1007
# Epoch 79/100 | val RMSE: 0.0985
# Epoch 80/100 | val RMSE: 0.0985
# Epoch 81/100 | val RMSE: 0.0982
# Epoch 82/100 | val RMSE: 0.0985
# Epoch 83/100 | val RMSE: 0.0982
# Epoch 84/100 | val RMSE: 0.0978
# Epoch 85/100 | val RMSE: 0.0973
# Epoch 86/100 | val RMSE: 0.0976
# Epoch 87/100 | val RMSE: 0.0972
# Epoch 88/100 | val RMSE: 0.0971
# Epoch 89/100 | val RMSE: 0.0968
# Epoch 90/100 | val RMSE: 0.0975
# Epoch 91/100 | val RMSE: 0.0964
# Epoch 92/100 | val RMSE: 0.0969
# Epoch 93/100 | val RMSE: 0.0967
# Epoch 94/100 | val RMSE: 0.0967
# Epoch 95/100 | val RMSE: 0.0968
# Epoch 96/100 | val RMSE: 0.0970
# Epoch 97/100 | val RMSE: 0.0969
# Epoch 98/100 | val RMSE: 0.0969
# Epoch 99/100 | val RMSE: 0.0969
# Epoch 100/100 | val RMSE: 0.0969
# Fold 4 CENTERED  RMSE 0.1989 | MAE 0.0257 | R² 0.9588 | RMAE 0.3402
# Fold 4 RAW  RMSE 838489.9509 | MAE 108295.3087 | R² 0.9588 | RMAE 0.3402
# === FOLD 5/8 ===
# Model compiled with torch.compile(mode='max-autotune')
# Using fused AdamW
# Start epoch train for fold 5
# Epoch 01/100 | val RMSE: 0.2276
# Epoch 02/100 | val RMSE: 0.1935
# Epoch 03/100 | val RMSE: 0.1669
# Epoch 04/100 | val RMSE: 0.1556
# Epoch 05/100 | val RMSE: 0.1500
# Epoch 06/100 | val RMSE: 0.1432
# Epoch 07/100 | val RMSE: 0.1433
# Epoch 08/100 | val RMSE: 0.1410
# Epoch 09/100 | val RMSE: 0.1404
# Epoch 10/100 | val RMSE: 0.1422
# Epoch 11/100 | val RMSE: 0.1436
# Epoch 12/100 | val RMSE: 0.1507
# Epoch 13/100 | val RMSE: 0.1362
# Epoch 14/100 | val RMSE: 0.1398
# Epoch 15/100 | val RMSE: 0.1343
# Epoch 16/100 | val RMSE: 0.1375
# Epoch 17/100 | val RMSE: 0.1323
# Epoch 18/100 | val RMSE: 0.1296
# Epoch 19/100 | val RMSE: 0.1322
# Epoch 20/100 | val RMSE: 0.1306
# Epoch 21/100 | val RMSE: 0.1279
# Epoch 22/100 | val RMSE: 0.1298
# Epoch 23/100 | val RMSE: 0.1318
# Epoch 24/100 | val RMSE: 0.1279
# Epoch 25/100 | val RMSE: 0.1273
# Epoch 26/100 | val RMSE: 0.1253
# Epoch 27/100 | val RMSE: 0.1243
# Epoch 28/100 | val RMSE: 0.1248
# Epoch 29/100 | val RMSE: 0.1253
# Epoch 30/100 | val RMSE: 0.1213
# Epoch 31/100 | val RMSE: 0.1216
# Epoch 32/100 | val RMSE: 0.1245
# Epoch 33/100 | val RMSE: 0.1179
# Epoch 34/100 | val RMSE: 0.1184
# Epoch 35/100 | val RMSE: 0.1189
# Epoch 36/100 | val RMSE: 0.1170
# Epoch 37/100 | val RMSE: 0.1214
# Epoch 38/100 | val RMSE: 0.1177
# Epoch 39/100 | val RMSE: 0.1157
# Epoch 40/100 | val RMSE: 0.1155
# Epoch 41/100 | val RMSE: 0.1164
# Epoch 42/100 | val RMSE: 0.1168
# Epoch 43/100 | val RMSE: 0.1138
# Epoch 44/100 | val RMSE: 0.1187
# Epoch 45/100 | val RMSE: 0.1142
# Epoch 46/100 | val RMSE: 0.1135
# Epoch 47/100 | val RMSE: 0.1125
# Epoch 48/100 | val RMSE: 0.1138
# Epoch 49/100 | val RMSE: 0.1109
# Epoch 50/100 | val RMSE: 0.1108
# Epoch 51/100 | val RMSE: 0.1111
# Epoch 52/100 | val RMSE: 0.1100
# Epoch 53/100 | val RMSE: 0.1132
# Epoch 54/100 | val RMSE: 0.1132
# Epoch 55/100 | val RMSE: 0.1113
# Epoch 56/100 | val RMSE: 0.1114
# Epoch 57/100 | val RMSE: 0.1090
# Epoch 58/100 | val RMSE: 0.1076
# Epoch 59/100 | val RMSE: 0.1071
# Epoch 60/100 | val RMSE: 0.1089
# Epoch 61/100 | val RMSE: 0.1113
# Epoch 62/100 | val RMSE: 0.1061
# Epoch 63/100 | val RMSE: 0.1074
# Epoch 64/100 | val RMSE: 0.1086
# Epoch 65/100 | val RMSE: 0.1072
# Epoch 66/100 | val RMSE: 0.1061
# Epoch 67/100 | val RMSE: 0.1086
# Epoch 68/100 | val RMSE: 0.1046
# Epoch 69/100 | val RMSE: 0.1066
# Epoch 70/100 | val RMSE: 0.1037
# Epoch 71/100 | val RMSE: 0.1052
# Epoch 72/100 | val RMSE: 0.1054
# Epoch 73/100 | val RMSE: 0.1044
# Epoch 74/100 | val RMSE: 0.1027
# Epoch 75/100 | val RMSE: 0.1038
# Epoch 76/100 | val RMSE: 0.1021
# Epoch 77/100 | val RMSE: 0.1010
# Epoch 78/100 | val RMSE: 0.1000
# Epoch 79/100 | val RMSE: 0.0990
# Epoch 80/100 | val RMSE: 0.1014
# Epoch 81/100 | val RMSE: 0.1014
# Epoch 82/100 | val RMSE: 0.0995
# Epoch 83/100 | val RMSE: 0.0996
# Epoch 84/100 | val RMSE: 0.0996
# Epoch 85/100 | val RMSE: 0.1000
# Epoch 86/100 | val RMSE: 0.0986
# Epoch 87/100 | val RMSE: 0.0994
# Epoch 88/100 | val RMSE: 0.0991
# Epoch 89/100 | val RMSE: 0.0998
# Epoch 90/100 | val RMSE: 0.0990
# Epoch 91/100 | val RMSE: 0.0984
# Epoch 92/100 | val RMSE: 0.0986
# Epoch 93/100 | val RMSE: 0.0984
# Epoch 94/100 | val RMSE: 0.0986
# Epoch 95/100 | val RMSE: 0.0987
# Epoch 96/100 | val RMSE: 0.0988
# Epoch 97/100 | val RMSE: 0.0985
# Epoch 98/100 | val RMSE: 0.0985
# Epoch 99/100 | val RMSE: 0.0985
# Epoch 100/100 | val RMSE: 0.0985
# Fold 5 CENTERED  RMSE 0.2290 | MAE 0.0237 | R² 0.9473 | RMAE 0.3158
# Fold 5 RAW  RMSE 965290.6806 | MAE 99949.0748 | R² 0.9473 | RMAE 0.3158
# === FOLD 6/8 ===
# Model compiled with torch.compile(mode='max-autotune')
# Using fused AdamW
# Start epoch train for fold 6
# Epoch 01/100 | val RMSE: 0.2398
# Epoch 02/100 | val RMSE: 0.2046
# Epoch 03/100 | val RMSE: 0.1751
# Epoch 04/100 | val RMSE: 0.1621
# Epoch 05/100 | val RMSE: 0.1533
# Epoch 06/100 | val RMSE: 0.1541
# Epoch 07/100 | val RMSE: 0.1495
# Epoch 08/100 | val RMSE: 0.1523
# Epoch 09/100 | val RMSE: 0.1468
# Epoch 10/100 | val RMSE: 0.1448
# Epoch 11/100 | val RMSE: 0.1481
# Epoch 12/100 | val RMSE: 0.1543
# Epoch 13/100 | val RMSE: 0.1503
# Epoch 14/100 | val RMSE: 0.1451
# Epoch 15/100 | val RMSE: 0.1463
# Epoch 16/100 | val RMSE: 0.1441
# Epoch 17/100 | val RMSE: 0.1409
# Epoch 18/100 | val RMSE: 0.1451
# Epoch 19/100 | val RMSE: 0.1395
# Epoch 20/100 | val RMSE: 0.1373
# Epoch 21/100 | val RMSE: 0.1393
# Epoch 22/100 | val RMSE: 0.1423
# Epoch 23/100 | val RMSE: 0.1376
# Epoch 24/100 | val RMSE: 0.1342
# Epoch 25/100 | val RMSE: 0.1332
# Epoch 26/100 | val RMSE: 0.1332
# Epoch 27/100 | val RMSE: 0.1302
# Epoch 28/100 | val RMSE: 0.1342
# Epoch 29/100 | val RMSE: 0.1288
# Epoch 30/100 | val RMSE: 0.1289
# Epoch 31/100 | val RMSE: 0.1240
# Epoch 32/100 | val RMSE: 0.1310
# Epoch 33/100 | val RMSE: 0.1276
# Epoch 34/100 | val RMSE: 0.1279
# Epoch 35/100 | val RMSE: 0.1341
# Epoch 36/100 | val RMSE: 0.1258
# Epoch 37/100 | val RMSE: 0.1269
# Epoch 38/100 | val RMSE: 0.1217
# Epoch 39/100 | val RMSE: 0.1215
# Epoch 40/100 | val RMSE: 0.1269
# Epoch 41/100 | val RMSE: 0.1234
# Epoch 42/100 | val RMSE: 0.1234
# Epoch 43/100 | val RMSE: 0.1185
# Epoch 44/100 | val RMSE: 0.1235
# Epoch 45/100 | val RMSE: 0.1258
# Epoch 46/100 | val RMSE: 0.1205
# Epoch 47/100 | val RMSE: 0.1190
# Epoch 48/100 | val RMSE: 0.1199
# Epoch 49/100 | val RMSE: 0.1220
# Epoch 50/100 | val RMSE: 0.1204
# Epoch 51/100 | val RMSE: 0.1182
# Epoch 52/100 | val RMSE: 0.1198
# Epoch 53/100 | val RMSE: 0.1183
# Epoch 54/100 | val RMSE: 0.1174
# Epoch 55/100 | val RMSE: 0.1171
# Epoch 56/100 | val RMSE: 0.1162
# Epoch 57/100 | val RMSE: 0.1151
# Epoch 58/100 | val RMSE: 0.1147
# Epoch 59/100 | val RMSE: 0.1155
# Epoch 60/100 | val RMSE: 0.1147
# Epoch 61/100 | val RMSE: 0.1132
# Epoch 62/100 | val RMSE: 0.1129
# Epoch 63/100 | val RMSE: 0.1116
# Epoch 64/100 | val RMSE: 0.1139
# Epoch 65/100 | val RMSE: 0.1118
# Epoch 66/100 | val RMSE: 0.1123
# Epoch 67/100 | val RMSE: 0.1150
# Epoch 68/100 | val RMSE: 0.1112
# Epoch 69/100 | val RMSE: 0.1108
# Epoch 70/100 | val RMSE: 0.1107
# Epoch 71/100 | val RMSE: 0.1109
# Epoch 72/100 | val RMSE: 0.1091
# Epoch 73/100 | val RMSE: 0.1112
# Epoch 74/100 | val RMSE: 0.1105
# Epoch 75/100 | val RMSE: 0.1107
# Epoch 76/100 | val RMSE: 0.1091
# Epoch 77/100 | val RMSE: 0.1131
# Epoch 78/100 | val RMSE: 0.1083
# Epoch 79/100 | val RMSE: 0.1100
# Epoch 80/100 | val RMSE: 0.1080
# Epoch 81/100 | val RMSE: 0.1082
# Epoch 82/100 | val RMSE: 0.1076
# Epoch 83/100 | val RMSE: 0.1076
# Epoch 84/100 | val RMSE: 0.1080
# Epoch 85/100 | val RMSE: 0.1071
# Epoch 86/100 | val RMSE: 0.1072
# Epoch 87/100 | val RMSE: 0.1067
# Epoch 88/100 | val RMSE: 0.1066
# Epoch 89/100 | val RMSE: 0.1069
# Epoch 90/100 | val RMSE: 0.1059
# Epoch 91/100 | val RMSE: 0.1063
# Epoch 92/100 | val RMSE: 0.1064
# Epoch 93/100 | val RMSE: 0.1063
# Epoch 94/100 | val RMSE: 0.1062
# Epoch 95/100 | val RMSE: 0.1063
# Epoch 96/100 | val RMSE: 0.1064
# Epoch 97/100 | val RMSE: 0.1064
# Epoch 98/100 | val RMSE: 0.1063
# Epoch 99/100 | val RMSE: 0.1063
# Epoch 100/100 | val RMSE: 0.1063
# Fold 6 CENTERED  RMSE 0.2789 | MAE 0.0226 | R² 0.9368 | RMAE 0.2812
# Fold 6 RAW  RMSE 1175708.3937 | MAE 95290.8645 | R² 0.9368 | RMAE 0.2812
# === FOLD 7/8 ===
# Model compiled with torch.compile(mode='max-autotune')
# Using fused AdamW
# Start epoch train for fold 7
# Epoch 01/100 | val RMSE: 0.2330
# Epoch 02/100 | val RMSE: 0.1981
# Epoch 03/100 | val RMSE: 0.1647
# Epoch 04/100 | val RMSE: 0.1535
# Epoch 05/100 | val RMSE: 0.1508
# Epoch 06/100 | val RMSE: 0.1519
# Epoch 07/100 | val RMSE: 0.1428
# Epoch 08/100 | val RMSE: 0.1451
# Epoch 09/100 | val RMSE: 0.1441
# Epoch 10/100 | val RMSE: 0.1380
# Epoch 11/100 | val RMSE: 0.1376
# Epoch 12/100 | val RMSE: 0.1424
# Epoch 13/100 | val RMSE: 0.1417
# Epoch 14/100 | val RMSE: 0.1398
# Epoch 15/100 | val RMSE: 0.1381
# Epoch 16/100 | val RMSE: 0.1358
# Epoch 17/100 | val RMSE: 0.1395
# Epoch 18/100 | val RMSE: 0.1379
# Epoch 19/100 | val RMSE: 0.1367
# Epoch 20/100 | val RMSE: 0.1353
# Epoch 21/100 | val RMSE: 0.1321
# Epoch 22/100 | val RMSE: 0.1409
# Epoch 23/100 | val RMSE: 0.1316
# Epoch 24/100 | val RMSE: 0.1332
# Epoch 25/100 | val RMSE: 0.1333
# Epoch 26/100 | val RMSE: 0.1353
# Epoch 27/100 | val RMSE: 0.1298
# Epoch 28/100 | val RMSE: 0.1323
# Epoch 29/100 | val RMSE: 0.1238
# Epoch 30/100 | val RMSE: 0.1249
# Epoch 31/100 | val RMSE: 0.1242
# Epoch 32/100 | val RMSE: 0.1206
# Epoch 33/100 | val RMSE: 0.1300
# Epoch 34/100 | val RMSE: 0.1194
# Epoch 35/100 | val RMSE: 0.1227
# Epoch 36/100 | val RMSE: 0.1184
# Epoch 37/100 | val RMSE: 0.1175
# Epoch 38/100 | val RMSE: 0.1198
# Epoch 39/100 | val RMSE: 0.1195
# Epoch 40/100 | val RMSE: 0.1174
# Epoch 41/100 | val RMSE: 0.1200
# Epoch 42/100 | val RMSE: 0.1202
# Epoch 43/100 | val RMSE: 0.1190
# Epoch 44/100 | val RMSE: 0.1160
# Epoch 45/100 | val RMSE: 0.1229
# Epoch 46/100 | val RMSE: 0.1138
# Epoch 47/100 | val RMSE: 0.1128
# Epoch 48/100 | val RMSE: 0.1156
# Epoch 49/100 | val RMSE: 0.1138
# Epoch 50/100 | val RMSE: 0.1122
# Epoch 51/100 | val RMSE: 0.1116
# Epoch 52/100 | val RMSE: 0.1105
# Epoch 53/100 | val RMSE: 0.1117
# Epoch 54/100 | val RMSE: 0.1106
# Epoch 55/100 | val RMSE: 0.1110
# Epoch 56/100 | val RMSE: 0.1093
# Epoch 57/100 | val RMSE: 0.1086
# Epoch 58/100 | val RMSE: 0.1093
# Epoch 59/100 | val RMSE: 0.1106
# Epoch 60/100 | val RMSE: 0.1095
# Epoch 61/100 | val RMSE: 0.1085
# Epoch 62/100 | val RMSE: 0.1085
# Epoch 63/100 | val RMSE: 0.1050
# Epoch 64/100 | val RMSE: 0.1060
# Epoch 65/100 | val RMSE: 0.1077
# Epoch 66/100 | val RMSE: 0.1073
# Epoch 67/100 | val RMSE: 0.1054
# Epoch 68/100 | val RMSE: 0.1066
# Epoch 69/100 | val RMSE: 0.1056
# Epoch 70/100 | val RMSE: 0.1063
# Epoch 71/100 | val RMSE: 0.1048
# Epoch 72/100 | val RMSE: 0.1040
# Epoch 73/100 | val RMSE: 0.1044
# Epoch 74/100 | val RMSE: 0.1050
# Epoch 75/100 | val RMSE: 0.1030
# Epoch 76/100 | val RMSE: 0.1039
# Epoch 77/100 | val RMSE: 0.1027
# Epoch 78/100 | val RMSE: 0.1021
# Epoch 79/100 | val RMSE: 0.1022
# Epoch 80/100 | val RMSE: 0.1020
# Epoch 81/100 | val RMSE: 0.1016
# Epoch 82/100 | val RMSE: 0.0995
# Epoch 83/100 | val RMSE: 0.1004
# Epoch 84/100 | val RMSE: 0.1006
# Epoch 85/100 | val RMSE: 0.1010
# Epoch 86/100 | val RMSE: 0.1009
# Epoch 87/100 | val RMSE: 0.1007
# Epoch 88/100 | val RMSE: 0.0997
# Epoch 89/100 | val RMSE: 0.0999
# Epoch 90/100 | val RMSE: 0.1002
# Epoch 91/100 | val RMSE: 0.0993
# Epoch 92/100 | val RMSE: 0.0996
# Epoch 93/100 | val RMSE: 0.0998
# Epoch 94/100 | val RMSE: 0.0994
# Epoch 95/100 | val RMSE: 0.0996
# Epoch 96/100 | val RMSE: 0.0995
# Epoch 97/100 | val RMSE: 0.0995
# Epoch 98/100 | val RMSE: 0.0994
# Epoch 99/100 | val RMSE: 0.0994
# Epoch 100/100 | val RMSE: 0.0994
# Fold 7 CENTERED  RMSE 0.3129 | MAE 0.0221 | R² 0.9133 | RMAE 0.2849
# Fold 7 RAW  RMSE 1319060.8772 | MAE 93177.6301 | R² 0.9133 | RMAE 0.2849
# === FOLD 8/8 ===
# Model compiled with torch.compile(mode='max-autotune')
# Using fused AdamW
# Start epoch train for fold 8
# Epoch 01/100 | val RMSE: 0.2354
# Epoch 02/100 | val RMSE: 0.1960
# Epoch 03/100 | val RMSE: 0.1647
# Epoch 04/100 | val RMSE: 0.1542
# Epoch 05/100 | val RMSE: 0.1484
# Epoch 06/100 | val RMSE: 0.1462
# Epoch 07/100 | val RMSE: 0.1423
# Epoch 08/100 | val RMSE: 0.1486
# Epoch 09/100 | val RMSE: 0.1464
# Epoch 10/100 | val RMSE: 0.1399
# Epoch 11/100 | val RMSE: 0.1419
# Epoch 12/100 | val RMSE: 0.1344
# Epoch 13/100 | val RMSE: 0.1357
# Epoch 14/100 | val RMSE: 0.1353
# Epoch 15/100 | val RMSE: 0.1326
# Epoch 16/100 | val RMSE: 0.1333
# Epoch 17/100 | val RMSE: 0.1285
# Epoch 18/100 | val RMSE: 0.1363
# Epoch 19/100 | val RMSE: 0.1315
# Epoch 20/100 | val RMSE: 0.1299
# Epoch 21/100 | val RMSE: 0.1301
# Epoch 22/100 | val RMSE: 0.1308
# Epoch 23/100 | val RMSE: 0.1284
# Epoch 24/100 | val RMSE: 0.1303
# Epoch 25/100 | val RMSE: 0.1288
# Epoch 26/100 | val RMSE: 0.1238
# Epoch 27/100 | val RMSE: 0.1327
# Epoch 28/100 | val RMSE: 0.1247
# Epoch 29/100 | val RMSE: 0.1232
# Epoch 30/100 | val RMSE: 0.1200
# Epoch 31/100 | val RMSE: 0.1181
# Epoch 32/100 | val RMSE: 0.1219
# Epoch 33/100 | val RMSE: 0.1169
# Epoch 34/100 | val RMSE: 0.1150
# Epoch 35/100 | val RMSE: 0.1192
# Epoch 36/100 | val RMSE: 0.1175
# Epoch 37/100 | val RMSE: 0.1170
# Epoch 38/100 | val RMSE: 0.1174
# Epoch 39/100 | val RMSE: 0.1180
# Epoch 40/100 | val RMSE: 0.1129
# Epoch 41/100 | val RMSE: 0.1121
# Epoch 42/100 | val RMSE: 0.1140
# Epoch 43/100 | val RMSE: 0.1181
# Epoch 44/100 | val RMSE: 0.1124
# Epoch 45/100 | val RMSE: 0.1142
# Epoch 46/100 | val RMSE: 0.1096
# Epoch 47/100 | val RMSE: 0.1118
# Epoch 48/100 | val RMSE: 0.1112
# Epoch 49/100 | val RMSE: 0.1086
# Epoch 50/100 | val RMSE: 0.1089
# Epoch 51/100 | val RMSE: 0.1087
# Epoch 52/100 | val RMSE: 0.1090
# Epoch 53/100 | val RMSE: 0.1063
# Epoch 54/100 | val RMSE: 0.1113
# Epoch 55/100 | val RMSE: 0.1082
# Epoch 56/100 | val RMSE: 0.1083
# Epoch 57/100 | val RMSE: 0.1088
# Epoch 58/100 | val RMSE: 0.1059
# Epoch 59/100 | val RMSE: 0.1042
# Epoch 60/100 | val RMSE: 0.1045
# Epoch 61/100 | val RMSE: 0.1074
# Epoch 62/100 | val RMSE: 0.1035
# Epoch 63/100 | val RMSE: 0.1039
# Epoch 64/100 | val RMSE: 0.1046
# Epoch 65/100 | val RMSE: 0.1031
# Epoch 66/100 | val RMSE: 0.1042
# Epoch 67/100 | val RMSE: 0.1033
# Epoch 68/100 | val RMSE: 0.1022
# Epoch 69/100 | val RMSE: 0.1010
# Epoch 70/100 | val RMSE: 0.1018
# Epoch 71/100 | val RMSE: 0.1001
# Epoch 72/100 | val RMSE: 0.1016
# Epoch 73/100 | val RMSE: 0.0996
# Epoch 74/100 | val RMSE: 0.0990
# Epoch 75/100 | val RMSE: 0.0984
# Epoch 76/100 | val RMSE: 0.0973
# Epoch 77/100 | val RMSE: 0.0977
# Epoch 78/100 | val RMSE: 0.0971
# Epoch 79/100 | val RMSE: 0.0984
# Epoch 80/100 | val RMSE: 0.0980
# Epoch 81/100 | val RMSE: 0.0976
# Epoch 82/100 | val RMSE: 0.0961
# Epoch 83/100 | val RMSE: 0.0970
# Epoch 84/100 | val RMSE: 0.0966
# Epoch 85/100 | val RMSE: 0.0961
# Epoch 86/100 | val RMSE: 0.0964
# Epoch 87/100 | val RMSE: 0.0966
# Epoch 88/100 | val RMSE: 0.0959
# Epoch 89/100 | val RMSE: 0.0962
# Epoch 90/100 | val RMSE: 0.0963
# Epoch 91/100 | val RMSE: 0.0957
# Epoch 92/100 | val RMSE: 0.0955
# Epoch 93/100 | val RMSE: 0.0953
# Epoch 94/100 | val RMSE: 0.0957
# Epoch 95/100 | val RMSE: 0.0954
# Epoch 96/100 | val RMSE: 0.0953
# Epoch 97/100 | val RMSE: 0.0951
# Epoch 98/100 | val RMSE: 0.0952
# Epoch 99/100 | val RMSE: 0.0952
# Epoch 100/100 | val RMSE: 0.0952
# Fold 8 CENTERED  RMSE 0.1892 | MAE 0.0201 | R² 0.9651 | RMAE 0.2557
# Fold 8 RAW  RMSE 797486.2196 | MAE 84854.4216 | R² 0.9651 | RMAE 0.2557

# %% [markdown]
# ## Save Model

# %%
torch.save({
  "model_state_dict": best_fold_state,
  "model_hyperparams": {
    "n_features": len(FEATURES),
    "n_dyads": len(dyad_to_idx),
    "n_layers": N_LAYERS,
    "embed_dim": EMBEDDING_SIZE,
    "hidden_size": HIDDEN_SIZE,
    "dropout": DROPOUT,
    "horizon": HORIZON,
    "type": XLSTM_TYPE,
    "layers": XLSTM_LAYERS,
  },
  "dyad_to_idx": dyad_to_idx,
  "feature_names": FEATURES,
}, PATH_TO_FOLDER + SERIAL_NUMBER + ".pt")
print("Saved model to", PATH_TO_FOLDER + SERIAL_NUMBER + ".pt")
# Out:
# Saved model to XLSTM(sm)-1e-05lr-0_05d-512hs-0_001wd-2048bs-3layers-256es-kfolds8-hp.pt

# %%
def summarize(xs):
  xs = np.asarray(xs, dtype=float)
  n = xs.size
  mean = xs.mean()
  std = xs.std(ddof=1)  # sample std
  se = std / math.sqrt(n)
  try:
    from scipy.stats import t
    tcrit = t.ppf(0.975, df=n - 1)
  except Exception:
    tcrit = 1.96  # normal approx≈
  ci95 = tcrit * se
  return mean, std, ci95

# %%
print("\n=== Cross-fold CENTERED summary ===")
for name in ["MAE", "RMSE", "R2", "RMAE"]:
  mean, std, ci = summarize(metrics_per_fold[name])
  print(f"{name:>5}: {mean:.4f} ± {std:.4f}  (95% CI ±{ci:.4f})")

print("\n=== Cross-fold RAW summary ===")
for name in ["MAE", "RMSE", "R2", "RMAE"]:
  mean, std, ci = summarize(metrics_per_fold_raw[name])
  print(f"{name:>5}: {mean:.4f} ± {std:.4f}  (95% CI ±{ci:.4f})")
# Out:
# === Cross-fold CENTERED summary ===
#   MAE: 0.0242 ± 0.0029  (95% CI ±0.0024)
#  RMSE: 0.3013 ± 0.1107  (95% CI ±0.0926)
#    R2: 0.9171 ± 0.0522  (95% CI ±0.0436)
#  RMAE: 0.3065 ± 0.0346  (95% CI ±0.0290)
#
# === Cross-fold RAW summary ===
#   MAE: 102124.6398 ± 12239.3763  (95% CI ±10232.3746)
#  RMSE: 1270225.9470 ± 466711.8691  (95% CI ±390180.8870)
#    R2: 0.9171 ± 0.0522  (95% CI ±0.0436)
#  RMAE: 0.3065 ± 0.0346  (95% CI ±0.0290)
