# %% [markdown]
# # xLSTM, sLSTM, mLSTMs - with Checkpoints

# %% [markdown]
# ## Preparation

# %% [markdown]
# ### Import modules

# %%
# Cell 1: Mount & Navigate
from google.colab import drive
from torch.version import cuda

drive.mount('/content/drive')

# Go to correct folder
# %cd /content/drive/MyDrive/Colab\ Notebooks/thesis/LSTM_Train

# Verify structure
# !ls -la ../
# Should show: dataset/  thesis_utils/  LSTM_Train/

# !pip install loguru torchxlstm fastparquet

import sys
from pathlib import Path

# Add thesis_utils to path (parent dir)
sys.path.insert(0, '/content/drive/MyDrive/Colab\ Notebooks/thesis')

# Or simpler:
sys.path.insert(0, str(Path.cwd().parent))
# Out:
# <>:20: SyntaxWarning: invalid escape sequence '\ '
# <>:20: SyntaxWarning: invalid escape sequence '\ '
# /tmp/ipython-input-2272185481.py:20: SyntaxWarning: invalid escape sequence '\ '
#   sys.path.insert(0, '/content/drive/MyDrive/Colab\ Notebooks/thesis')
# Mounted at /content/drive
# /content/drive/MyDrive/Colab Notebooks/thesis/LSTM_Train
# total 29
# drwx------ 2 root root 4096 Dec 28 22:19  checkpoints
# drwx------ 2 root root 4096 Dec 25 14:57  dataset
# drwx------ 2 root root 4096 Dec 25 18:09  GRU_Train
# drwx------ 2 root root 4096 Dec 25 14:56  LSTM_Train
# drwx------ 2 root root 4096 Dec 26 10:59 'MLSTM   SLSTM'
# -rw------- 1 root root  662 Dec 25 15:12  requirements_colab.txt
# drwx------ 2 root root 4096 Dec 25 14:56  thesis_utils
# drwx------ 2 root root 4096 Dec 25 22:13  XLSTM_Train
# Collecting loguru
#   Downloading loguru-0.7.3-py3-none-any.whl.metadata (22 kB)
# Collecting torchxlstm
#   Downloading torchxlstm-0.0.3-py3-none-any.whl.metadata (1.3 kB)
# Collecting fastparquet
#   Downloading fastparquet-2025.12.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (4.4 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from torchxlstm) (2.9.0+cu126)
# Requirement already satisfied: pandas>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from fastparquet) (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from fastparquet) (2.0.2)
# Requirement already satisfied: cramjam>=2.3 in /usr/local/lib/python3.12/dist-packages (from fastparquet) (2.11.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from fastparquet) (2025.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from fastparquet) (25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.0->fastparquet) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.0->fastparquet) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.0->fastparquet) (2025.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->torchxlstm) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->torchxlstm) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->torchxlstm) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->torchxlstm) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->torchxlstm) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->torchxlstm) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->torchxlstm) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->torchxlstm) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch->torchxlstm) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->torchxlstm) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->torchxlstm) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch->torchxlstm) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch->torchxlstm) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch->torchxlstm) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch->torchxlstm) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->torchxlstm) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch->torchxlstm) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch->torchxlstm) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->torchxlstm) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch->torchxlstm) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch->torchxlstm) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch->torchxlstm) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.5.0->fastparquet) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->torchxlstm) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->torchxlstm) (3.0.3)
# Downloading loguru-0.7.3-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 5.2 MB/s eta 0:00:00
# Downloading torchxlstm-0.0.3-py3-none-any.whl (4.6 kB)
# Downloading fastparquet-2025.12.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 99.3 MB/s eta 0:00:00
# Installing collected packages: loguru, fastparquet, torchxlstm
# Successfully installed fastparquet-2025.12.0 loguru-0.7.3 torchxlstm-0.0.3

# %%
# Prediction using LSTM, GRU-LSTM, xLSTM
import copy
import math
import os
from typing import List

import numpy as np
import pandas as pd

import torch
import torch.nn as nn
import torch.optim as optim
from torch.nn.utils import clip_grad_norm_
from torch.optim import Optimizer
from torch.optim.lr_scheduler import LRScheduler
from torch.utils.data import DataLoader, Dataset, Subset

from sklearn.model_selection import KFold, GroupShuffleSplit

import thesis_utils as tu

from torch.amp import GradScaler, autocast

# %%
CHKPT_DIR = "/content/checkpoints"
os.makedirs(CHKPT_DIR, exist_ok=True)

# %%
def ckpt_path(serial, fold):
  return os.path.join(CHKPT_DIR, f"{serial}_fold{fold}.pt")

# %%
def safe_load_ckpt(path: str, map_location="cpu"):
  """Load a torch checkpoint, but delete it and return None if corrupted."""
  if not os.path.exists(path):
    return None

  try:
    return torch.load(path, map_location=map_location)
  except Exception as e:
    print(f"⚠️ Corrupted checkpoint detected: {path}")
    print(f"   Error: {e}")
    # Delete immediately so it cannot be loaded again later
    try:
      os.remove(path)
      print("   Deleted corrupted checkpoint.")
    except Exception as del_e:
      print(f"   Could not delete checkpoint: {del_e}")
    return None

# %% [markdown]
# ### Configuration

# %%
# Model parameters
HORIZON = 1
BATCH_SIZE = 2048  # Increased to saturate GPU
EMBEDDING_SIZE = 256
NUM_EPOCHS = 100
HIDDEN_SIZE = 768
N_LAYERS = 3
DROPOUT = 0.05
XLSTM_TYPE = "X"
N_LAGS = 5

# Train parameters
TARGET = "EXPORT_centered"
FEATURES = [
  "contig", "comlang_off", "colony", "smctry",
]
N_SPLITS = 8
PATIENCE = 10
LEARNING_RATE = 1e-5
WEIGHT_DECAY = 1e-3
RANDOM_SEED = 16
SUBSAMPLE_ENABLED = False
N_DYADS = 10
XLSTM_LAYERS = "smsm"

SANCTION_COLS = ["arms", "military", "trade", "travel", "other", "financial"]

# Torch config
torch.manual_seed(RANDOM_SEED)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# ----------------------------
# Colab / L4 performance knobs
# ----------------------------
if device.type == "cuda":
  print("GPU:", torch.cuda.get_device_name(0))
  print("CUDA:", torch.version.cuda, "| PyTorch:", torch.__version__)
  # !nvidia-smi -L

  # cuDNN autotuner (best when shapes are stable, typical in training)
  torch.backends.cudnn.benchmark = True

  # Better GEMM kernels on Ampere+ (L4 is Ada)
  torch.set_float32_matmul_precision("high")

  # Reduce allocator fragmentation for long runs
  os.environ.setdefault("PYTORCH_CUDA_ALLOC_CONF", "expandable_segments:True")

# Mixed precision (L4 supports bf16 well)
USE_AMP = True
AMP_DTYPE = torch.bfloat16 if (
    device.type == "cuda" and getattr(torch.cuda, "is_bf16_supported", lambda: False)()) else torch.float16

# torch.compile can improve throughput (PyTorch 2.0+)
USE_TORCH_COMPILE = True
COMPILE_MODE = "max-autotune"  # alternatives: "reduce-overhead", "default"

# GradScaler is needed for fp16; for bf16 it should be disabled
USE_GRAD_SCALER = (device.type == "cuda" and USE_AMP and AMP_DTYPE == torch.float16)

print("Using device:", device)
if torch.cuda.is_available():
  print(torch.cuda.get_device_name(0))
  # Enable TF32 for faster computing on Ampere+ GPUs
  torch.backends.cuda.matmul.allow_tf32 = True
  torch.backends.cudnn.allow_tf32 = True

dyads_case_study = [
  # "USA_CHN", "CHN_USA",
  # "USA_CAN", "CAN_USA",
  # "DEU_CHN", "CHN_DEU",
  # "USA_DEU", "DEU_USA",
  # "USA_MEX", "MEX_USA",
  # "AUS_CHN", "CHN_AUS",
  # "USA_JPN", "JPN_USA",
  # "DEU_JPN", "JPN_DEU",
  # "USA_AUS", "AUS_USA",
  # "DEU_RUS", "RUS_DEU",
]
# Out:
# GPU: NVIDIA L4
# CUDA: 12.6 | PyTorch: 2.9.0+cu126
# GPU 0: NVIDIA L4 (UUID: GPU-9ef834c6-5a3c-ad98-bf7f-8edd878bd8b8)
# Using device: cuda
# NVIDIA L4
# /usr/local/lib/python3.12/dist-packages/torch/__init__.py:1617: UserWarning: Please use the new API settings to control TF32 behavior, such as torch.backends.cudnn.conv.fp32_precision = 'tf32' or torch.backends.cuda.matmul.fp32_precision = 'ieee'. Old settings, e.g, torch.backends.cuda.matmul.allow_tf32 = True, torch.backends.cudnn.allow_tf32 = True, allowTF32CuDNN() and allowTF32CuBLAS() will be deprecated after Pytorch 2.9. Please see https://pytorch.org/docs/main/notes/cuda.html#tensorfloat-32-tf32-on-ampere-and-later-devices (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:80.)
#   _C._set_float32_matmul_precision(precision)

# %%
# Save config
SAVE_ENABLED = False
layers_string = f"({XLSTM_LAYERS})"
SERIAL_NUMBER = (
  f"{XLSTM_TYPE}LSTM"
  f"{layers_string if XLSTM_TYPE == 'X' else ''}"
  f"-{LEARNING_RATE}lr-{DROPOUT}d-{HIDDEN_SIZE}hs-{WEIGHT_DECAY}wd-{BATCH_SIZE}bs-{N_LAYERS}layers-{EMBEDDING_SIZE}es-kfolds{N_SPLITS}-hp"
)
SERIAL_NUMBER = SERIAL_NUMBER.replace(".", "_")
PATH_TO_FOLDER = ""

# %% [markdown]
# ### Load Data

# %%
from pandas import DataFrame

processed = pd.read_parquet(path="../dataset/processed.parquet", engine="fastparquet")
df: DataFrame = processed.copy(deep=True)

# %% [markdown]
# ### Sort, shift and compute data

# %%
# Sort data by Report + Partner + Year
df["dyad_id"] = df["ISO3_reporter"] + "_" + df["ISO3_partner"]
df = df.sort_values(by=["dyad_id", "Year"], ignore_index=True)

# %%
# Remove case study dyad_pairs
mask_keep = ~np.isin(df["dyad_id"], dyads_case_study)
df = df.loc[mask_keep].reset_index(drop=True)

# %%
# Sanity check case study pairs
has_overlap = df["dyad_id"].isin(dyads_case_study).any()

if has_overlap:
  print("⚠️ Some case study dyads are present in the DataFrame.")
else:
  print("✅ No case study dyads found in the DataFrame.")
# Out:
# ✅ No case study dyads found in the DataFrame.

# %%
if SUBSAMPLE_ENABLED:
  dyad_subsample = pd.Series(df["dyad_id"].unique()).sample(n=N_DYADS, random_state=RANDOM_SEED, replace=False)
  df = df[df["dyad_id"].isin(dyad_subsample)]

print(f"Unique dyads: {df["dyad_id"].nunique()}")
# Out:
# Unique dyads: 33672

# %%
df["sanction"] = (df[SANCTION_COLS]
                  .sum(axis=1)).astype(int)

# %% [markdown]
# ### Coerce numerical values and convert dyad_id to categorical

# %%
num_cols = ["distw", "GDP_reporter", "GDP_partner", "sanction", "contig",
            "comlang_off", "colony", "smctry", "Year", ]
df[num_cols] = df[num_cols].apply(pd.to_numeric, errors="coerce").astype(float)
df = df.dropna(subset=num_cols)

# %%
df["Year"] = df["Year"].astype(int)
for col in ["dyad_id"]:
  df[col] = pd.Categorical(df[col], categories=sorted(df[col].unique()))

# %%
# Save EXPORT std and median to undo centering
EXPORT_STD = df["EXPORT"].std()
EXPORT_MEDIAN = df["EXPORT"].median()

# %% [markdown]
# ### Center data

# %%
center_columns = ["distw", "GDP_reporter", "GDP_partner", "EXPORT"]
for col in center_columns:
  median = df[col].median()
  std_df = df[col].std()
  df[col + "_centered"] = (df[col] - median) / std_df
FEATURES += ["distw_centered"]

# %%
lag_cols = ["GDP_reporter_centered", "GDP_partner_centered", "sanction"]
for col in lag_cols:
  for index in range(1, N_LAGS + 1):
    df[f"{col}_lag{index}"] = df.groupby("dyad_id", observed=True)[col].shift(index)

# %%
df = df.dropna()

# %%
FEATURES += [f"{c}_lag{index}" for c in lag_cols for index in range(1, N_LAGS + 1)]

# %% [markdown]
# ## Split data

# %%
# Embeddings
dyad_to_idx = { dyad: i for i, dyad in enumerate(df["dyad_id"].cat.categories) }
df["dyad_idx"] = df["dyad_id"].map(dyad_to_idx).astype(int)

# %%
# Split into Train, Validation and Test sets
gss = GroupShuffleSplit(n_splits=1, test_size=0.2, random_state=RANDOM_SEED)

train_idx, test_idx = next(gss.split(df, groups=df["dyad_id"]))
test_df = df.iloc[test_idx]
train_df = df.iloc[train_idx]

train_idx, val_idx = next(gss.split(train_df, groups=train_df["dyad_id"]))
val_df = train_df.iloc[val_idx]
train_df = train_df.iloc[train_idx]

# %%
train_df.loc[:, FEATURES] = train_df.loc[:, FEATURES].astype(
  "float32",
  copy=False
)

# %% [markdown]
# # Train

# %% [markdown]
# ## Define Fold and Epoch steps
# _For reusability_

# %%
# Create KFold object
kf = KFold(n_splits=N_SPLITS, shuffle=True, random_state=RANDOM_SEED)

# %%
def epoch_step(
    model: nn.Module,
    optimizer: Optimizer,
    criterion: nn.Module,
    scheduler: LRScheduler,
    train_loader: DataLoader,
    val_loader: DataLoader,
    device: any,
    scaler: torch.amp.GradScaler,
) -> float:
  # =========================
  # TRAIN
  # =========================
  model.train()

  for X, y, di in train_loader:
    X, y, di = map(lambda t: t.to(device, non_blocking=True), (X, y, di))

    optimizer.zero_grad(set_to_none=True)

    # --- AMP forward ---
    with autocast("cuda"):
      y_pred = model(X, di)

      if not torch.isfinite(y_pred).all():
        print("⚠️ NaN or Inf detected in y_pred — stopping here!")
        return float("inf")

      loss = criterion(y_pred, y)

    if not torch.isfinite(loss):
      print("⚠️ loss is NaN or Inf!")
      return float("inf")

    # --- AMP backward ---
    scaler.scale(loss).backward()

    # IMPORTANT: unscale before clipping
    scaler.unscale_(optimizer)
    clip_grad_norm_(model.parameters(), max_norm=0.3)

    scaler.step(optimizer)
    scaler.update()

    # OneCycleLR MUST step per batch
    scheduler.step()

  # =========================
  # VALIDATION
  # =========================
  model.eval()
  val_losses = []

  with torch.no_grad():
    for X, y, di in val_loader:
      X, y, di = map(lambda t: t.to(device, non_blocking=True), (X, y, di))
      with autocast("cuda"):
        preds = model(X, di)
        val_losses.append(criterion(preds, y).item())

  val_rmse = math.sqrt(sum(val_losses) / len(val_losses))
  return val_rmse

# %%
def _make_loader(subset, *, batch_size: int, shuffle: bool, n_workers: int) -> DataLoader:
  """Colab-friendly DataLoader with aggressive prefetch + pinned memory."""
  kwargs = dict(
    batch_size=batch_size,
    shuffle=shuffle,
    num_workers=n_workers,
    pin_memory=True,
    persistent_workers=(n_workers > 0),
  )

  # Only valid when num_workers > 0
  if n_workers > 0:
    kwargs["prefetch_factor"] = 4

  return DataLoader(subset, **kwargs)

# %%
# Define fold step
def fold_step(
    fold: int,
    train_idx: List,
    val_idx: List,
    dataset: Dataset,
    batch_size: int,
    num_epochs: int,
    model: nn.Module,
    device: any,
    optimizer: Optimizer,
    criterion: nn.Module,
    serial: str,
):
  # Use all available cores
  n_workers = min(8, (os.cpu_count() or 2))

  train_loader = _make_loader(Subset(dataset, train_idx), batch_size=batch_size, shuffle=True, n_workers=n_workers)
  val_loader = _make_loader(Subset(dataset, val_idx), batch_size=batch_size, shuffle=False, n_workers=n_workers)

  scheduler = torch.optim.lr_scheduler.OneCycleLR(
    optimizer,
    max_lr=7e-4,
    epochs=NUM_EPOCHS,
    steps_per_epoch=len(train_loader),
    div_factor=25,
    final_div_factor=100,
    pct_start=0.3,
    anneal_strategy="cos",
    three_phase=False,
  )

  ckpt_file = ckpt_path(serial, fold)
  tmp_ckpt_file = ckpt_file + ".tmp"

  ckpt = safe_load_ckpt(ckpt_file, map_location=device)

  start_epoch = 0
  best_rmse = float("inf")
  best_state = copy.deepcopy(model.state_dict())
  scaler = GradScaler("cuda", enabled=USE_GRAD_SCALER)

  if ckpt is not None:
    print(f"🔄 Resuming from checkpoint: {ckpt_file}")

    model.load_state_dict(ckpt["model_state"])
    optimizer.load_state_dict(ckpt["optimizer_state"])
    scheduler.load_state_dict(ckpt["scheduler_state"])
    scaler.load_state_dict(ckpt["scaler_state"])

    start_epoch = ckpt["epoch"] + 1
    best_rmse = ckpt["best_rmse"]
    best_state = ckpt["best_state"]

  print(f"Start epoch train for fold {fold}")

  for epoch in range(start_epoch, num_epochs):
    val_rmse = epoch_step(
      model=model,
      optimizer=optimizer,
      criterion=criterion,
      scheduler=scheduler,
      train_loader=train_loader,
      val_loader=val_loader,
      device=device,
      scaler=scaler,
    )

    print(f"Epoch {epoch + 1:02d}/{num_epochs} | val RMSE: {val_rmse:.4f}")

    if val_rmse < best_rmse - 1e-4:
      best_rmse = val_rmse
      best_state = copy.deepcopy(model.state_dict())

    # =========================
    # ATOMIC CHECKPOINT SAVE
    # =========================
    state = {
      "epoch": epoch,
      "model_state": model.state_dict(),
      "optimizer_state": optimizer.state_dict(),
      "scheduler_state": scheduler.state_dict(),
      "scaler_state": scaler.state_dict(),
      "best_rmse": best_rmse,
      "best_state": best_state,
    }

    torch.save(state, tmp_ckpt_file)
    os.replace(tmp_ckpt_file, ckpt_file)

  # =========================
  # FINAL EVALUATION
  # =========================
  model.load_state_dict(best_state)
  model.eval()

  preds_centered, truth_centered = [], []

  with torch.inference_mode():
    for X, y, di in val_loader:
      X, di = map(lambda t: t.to(device, non_blocking=True), (X, di))

      with autocast("cuda", enabled=(getattr(device, "type", "cpu") == "cuda" and USE_AMP)):
        out = model(X, di)

        preds_centered.append(out.float().cpu())
        truth_centered.append(y)

  preds_centered = torch.cat(preds_centered).numpy()
  truth_centered = torch.cat(truth_centered).numpy()

  # Convert back to raw scale
  preds_raw = preds_centered * EXPORT_STD + EXPORT_MEDIAN
  truth_raw = truth_centered * EXPORT_STD + EXPORT_MEDIAN

  rmse_centered = tu.rmse(truth_centered, preds_centered)
  mae_centered = tu.mae(truth_centered, preds_centered)
  rmae_centered = tu.rmae(truth_centered, preds_centered)
  pseudo_r2_centered = tu.pseudo_r2(truth_centered, preds_centered)

  print(
    f"Fold {fold} CENTERED  RMSE {rmse_centered:.4f} | "
    f"MAE {mae_centered:.4f} | R² {pseudo_r2_centered:.4f} | "
    f"RMAE {rmae_centered:.4f}"
  )

  rmse_raw = tu.rmse(truth_raw, preds_raw)
  mae_raw = tu.mae(truth_raw, preds_raw)
  rmae_raw = tu.rmae(truth_raw, preds_raw)
  pseudo_r2_raw = tu.pseudo_r2(truth_raw, preds_raw)

  print(
    f"Fold {fold} RAW  RMSE {rmse_raw:.4f} | "
    f"MAE {mae_raw:.4f} | R² {pseudo_r2_raw:.4f} | "
    f"RMAE {rmae_raw:.4f}"
  )

  return (
    { "RMSE": rmse_centered, "MAE": mae_centered, "R2": pseudo_r2_centered, "RMAE": rmae_centered },
    { "RMSE": rmse_raw, "MAE": mae_raw, "R2": pseudo_r2_raw, "RMAE": rmae_raw },
    copy.deepcopy(best_state),
  )

# %% [markdown]
# ## Train Raw dataset

# %% [markdown]
# ### Split dataset

# %%
# Convert df_scaled to pytorch Tensor
dataset, dyad_to_idx = tu.make_panel_datasets_dyad(
  data=df,
  features=FEATURES,
  target=TARGET,
  horizon=HORIZON,
)

# %%
# Create DataLoaders for the 3 sets
n_workers = min(8, (os.cpu_count() or 2))

train_kwargs = dict(
  batch_size=BATCH_SIZE,
  shuffle=True,
  num_workers=n_workers,
  persistent_workers=(n_workers > 0),
  pin_memory=True,
)
val_kwargs = dict(
  batch_size=BATCH_SIZE,
  shuffle=False,
  num_workers=n_workers,
  persistent_workers=(n_workers > 0),
  pin_memory=True,
)
test_kwargs = dict(
  batch_size=BATCH_SIZE,
  shuffle=False,
  num_workers=n_workers,
  persistent_workers=(n_workers > 0),
  pin_memory=True,
)

if n_workers > 0:
  train_kwargs["prefetch_factor"] = 4
  val_kwargs["prefetch_factor"] = 4
  test_kwargs["prefetch_factor"] = 4

train_loader = DataLoader(Subset(dataset, train_idx), **train_kwargs)
val_loader = DataLoader(Subset(dataset, val_idx), **val_kwargs)
test_loader = DataLoader(Subset(dataset, test_idx), **test_kwargs)

# %% [markdown]
# ### Train model

# %%
# Save best train iteration
best_fold_state = None
best_fold_rmse = float("inf")

metrics_per_fold = {
  "RMSE": [],
  "MAE": [],
  "R2": [],
  "RMAE": [],
}

metrics_per_fold_raw = {
  "RMSE": [],
  "MAE": [],
  "R2": [],
  "RMAE": [],
}

# %%
for fold, (train_idx, val_idx) in enumerate(kf.split(np.arange(len(dataset))), 1):

  ckpt_file = ckpt_path(SERIAL_NUMBER, fold)
  ckpt = safe_load_ckpt(ckpt_file, map_location="cpu")

  if ckpt is not None and ckpt.get("epoch", -1) >= NUM_EPOCHS - 1:
    print(f"✅ Fold {fold} already completed — skipping.")
    continue

  print(f"=== FOLD {fold}/{N_SPLITS} ===")

  model = tu.DyadXLSTM(
    n_features=len(FEATURES),
    n_dyads=len(dyad_to_idx),
    embed_dim=EMBEDDING_SIZE,
    hidden_size=HIDDEN_SIZE,
    dropout=DROPOUT,
    horizon=HORIZON,
    type=XLSTM_TYPE,
    layers=XLSTM_LAYERS,
    n_layers=N_LAYERS,
  ).to(device=device)

  # JIT Compile the model for speedup (requires PyTorch 2.0+)
  if USE_TORCH_COMPILE and hasattr(torch, "compile") and device.type == "cuda":
    try:
      model = torch.compile(model, mode=COMPILE_MODE)
      print(f"Model compiled with torch.compile(mode={COMPILE_MODE!r})")
    except Exception as e:
      print(f"Could not compile model: {e}")

  criterion = nn.SmoothL1Loss(beta=0.5)

  adamw_kwargs = dict(lr=LEARNING_RATE, weight_decay=WEIGHT_DECAY, betas=(0.9, 0.95), eps=1e-8)
  if device.type == "cuda":
    try:
      optimizer = optim.AdamW(model.parameters(), **adamw_kwargs, fused=True)
      print("Using fused AdamW")
    except TypeError:
      optimizer = optim.AdamW(model.parameters(), **adamw_kwargs)
  else:
    optimizer = optim.AdamW(model.parameters(), **adamw_kwargs)

  fold_metrics, fold_metrics_raw, best_state = fold_step(fold=fold,
                                                         train_idx=train_idx,
                                                         val_idx=val_idx,
                                                         dataset=dataset,
                                                         batch_size=BATCH_SIZE,
                                                         num_epochs=NUM_EPOCHS,
                                                         model=model,
                                                         device=device,
                                                         optimizer=optimizer,
                                                         criterion=criterion,
                                                         serial=SERIAL_NUMBER)

  if fold_metrics["RMSE"] < best_fold_rmse:
    best_fold_rmse = fold_metrics["RMSE"]
    best_fold_state = copy.deepcopy(best_state)

  for k, v in fold_metrics.items():
    metrics_per_fold[k].append(v)

  for k, v in fold_metrics_raw.items():
    metrics_per_fold_raw[k].append(v)
# Out:
# === FOLD 1/8 ===
# Model compiled with torch.compile(mode='max-autotune')
# Using fused AdamW
# Start epoch train for fold 1
# W1229 00:36:13.858000 2316 torch/_inductor/utils.py:1558] [0/0] Not enough SMs to use max_autotune_gemm mode
# Autotune Choices Stats:
# {"num_choices": 2, "num_triton_choices": 0, "best_kernel": "bias_addmm", "best_time": 0.08806400001049042}
# AUTOTUNE addmm(2048x1024, 2048x768, 768x1024)
# strides: [0, 1], [768, 1], [1, 768]
# dtypes: torch.float16, torch.float16, torch.float16
#   bias_addmm 0.0881 ms 100.0%
#   addmm 0.0983 ms 89.6%
# SingleProcess AUTOTUNE benchmarking takes 0.4888 seconds and 0.0004 seconds precompiling for 2 choices
# Autotune Choices Stats:
# {"num_choices": 2, "num_triton_choices": 0, "best_kernel": "bias_addmm", "best_time": 0.062463998794555664}
# AUTOTUNE addmm(2048x768, 2048x552, 552x768)
# strides: [0, 1], [552, 1], [1, 552]
# dtypes: torch.float16, torch.float16, torch.float16
#   bias_addmm 0.0625 ms 100.0%
#   addmm 0.0881 ms 70.9%
# SingleProcess AUTOTUNE benchmarking takes 0.0935 seconds and 0.0002 seconds precompiling for 2 choices
# Autotune Choices Stats:
# {"num_choices": 2, "num_triton_choices": 0, "best_kernel": "bias_addmm", "best_time": 0.03993599861860275}
# AUTOTUNE addmm(2048x768, 2048x276, 276x768)
# strides: [0, 1], [276, 1], [1, 276]
# dtypes: torch.float16, torch.float16, torch.float16
#   bias_addmm 0.0399 ms 100.0%
#   addmm 0.0584 ms 68.4%
# SingleProcess AUTOTUNE benchmarking takes 0.0955 seconds and 0.0002 seconds precompiling for 2 choices
# Autotune Choices Stats:
# {"num_choices": 2, "num_triton_choices": 0, "best_kernel": "bias_addmm", "best_time": 0.03891199827194214}
# AUTOTUNE addmm(2048x552, 2048x276, 276x552)
# strides: [0, 1], [276, 1], [1, 276]
# dtypes: torch.float16, torch.float16, torch.float16
#   bias_addmm 0.0389 ms 100.0%
#   addmm 0.0502 ms 77.6%
# SingleProcess AUTOTUNE benchmarking takes 0.0891 seconds and 0.0002 seconds precompiling for 2 choices
# Autotune Choices Stats:
# {"num_choices": 2, "num_triton_choices": 0, "best_kernel": "bias_addmm", "best_time": 0.050175998359918594}
# AUTOTUNE addmm(1224x1024, 1224x768, 768x1024)
# strides: [0, 1], [768, 1], [1, 768]
# dtypes: torch.float16, torch.float16, torch.float16
#   bias_addmm 0.0502 ms 100.0%
#   addmm 0.0809 ms 62.0%
# SingleProcess AUTOTUNE benchmarking takes 0.0954 seconds and 0.0004 seconds precompiling for 2 choices
# Autotune Choices Stats:
# {"num_choices": 2, "num_triton_choices": 0, "best_kernel": "bias_addmm", "best_time": 0.05427199974656105}
# AUTOTUNE addmm(1224x768, 1224x552, 552x768)
# strides: [0, 1], [552, 1], [1, 552]
# dtypes: torch.float16, torch.float16, torch.float16
#   bias_addmm 0.0543 ms 100.0%
#   addmm 0.0584 ms 93.0%
# SingleProcess AUTOTUNE benchmarking takes 0.0905 seconds and 0.0002 seconds precompiling for 2 choices
# Autotune Choices Stats:
# {"num_choices": 2, "num_triton_choices": 0, "best_kernel": "bias_addmm", "best_time": 0.035840000957250595}
# AUTOTUNE addmm(1224x768, 1224x276, 276x768)
# strides: [0, 1], [276, 1], [1, 276]
# dtypes: torch.float16, torch.float16, torch.float16
#   bias_addmm 0.0358 ms 100.0%
#   addmm 0.0471 ms 76.1%
# SingleProcess AUTOTUNE benchmarking takes 0.0901 seconds and 0.0002 seconds precompiling for 2 choices
# Autotune Choices Stats:
# {"num_choices": 2, "num_triton_choices": 0, "best_kernel": "bias_addmm", "best_time": 0.02457600086927414}
# AUTOTUNE addmm(1224x552, 1224x276, 276x552)
# strides: [0, 1], [276, 1], [1, 276]
# dtypes: torch.float16, torch.float16, torch.float16
#   bias_addmm 0.0246 ms 100.0%
#   addmm 0.0297 ms 82.7%
# SingleProcess AUTOTUNE benchmarking takes 0.0886 seconds and 0.0002 seconds precompiling for 2 choices
# Epoch 01/100 | val RMSE: 0.2266
# Epoch 02/100 | val RMSE: 0.1773
# Epoch 03/100 | val RMSE: 0.1664
# Epoch 04/100 | val RMSE: 0.1612
# Epoch 05/100 | val RMSE: 0.1596
# Epoch 06/100 | val RMSE: 0.1524
# Epoch 07/100 | val RMSE: 0.1648
# Epoch 08/100 | val RMSE: 0.1551
# Epoch 09/100 | val RMSE: 0.1523
# Epoch 10/100 | val RMSE: 0.1625
# Epoch 11/100 | val RMSE: 0.1512
# Epoch 12/100 | val RMSE: 0.1566
# Epoch 13/100 | val RMSE: 0.1585
# Epoch 14/100 | val RMSE: 0.1573
# Epoch 15/100 | val RMSE: 0.1511
# Epoch 16/100 | val RMSE: 0.1486
# Epoch 17/100 | val RMSE: 0.1544
# Epoch 18/100 | val RMSE: 0.1572
# Epoch 19/100 | val RMSE: 0.1530
# Epoch 20/100 | val RMSE: 0.1604
# Epoch 21/100 | val RMSE: 0.1710
# Epoch 22/100 | val RMSE: 0.1498
# Epoch 23/100 | val RMSE: 0.1500
# Epoch 24/100 | val RMSE: 0.1521
# Epoch 25/100 | val RMSE: 0.1463
# Epoch 26/100 | val RMSE: 0.1413
# Epoch 27/100 | val RMSE: 0.1436
# Epoch 28/100 | val RMSE: 0.2059
# Epoch 29/100 | val RMSE: 0.1450
# Epoch 30/100 | val RMSE: 0.1394
# Epoch 31/100 | val RMSE: 0.1387
# Epoch 32/100 | val RMSE: 0.1372
# Epoch 33/100 | val RMSE: 0.1406
# Epoch 34/100 | val RMSE: 0.1429
# Epoch 35/100 | val RMSE: 0.1396
# Epoch 36/100 | val RMSE: 0.1380
# Epoch 37/100 | val RMSE: 0.1402
# Epoch 38/100 | val RMSE: 0.1375
# Epoch 39/100 | val RMSE: 0.1372
# Epoch 40/100 | val RMSE: 0.1330
# Epoch 41/100 | val RMSE: 0.1311
# Epoch 42/100 | val RMSE: 0.1335
# Epoch 43/100 | val RMSE: 0.1306
# Epoch 44/100 | val RMSE: 0.1313
# Epoch 45/100 | val RMSE: 0.1339
# Epoch 46/100 | val RMSE: 0.1335
# Epoch 47/100 | val RMSE: 0.1351
# Epoch 48/100 | val RMSE: 0.1327
# Epoch 49/100 | val RMSE: 0.1310
# Epoch 50/100 | val RMSE: 0.1363
# Epoch 51/100 | val RMSE: 0.1354
# Epoch 52/100 | val RMSE: 0.1291
# Epoch 53/100 | val RMSE: 0.1274
# Epoch 54/100 | val RMSE: 0.1271
# Epoch 55/100 | val RMSE: 0.1287
# Epoch 56/100 | val RMSE: 0.1441
# Epoch 57/100 | val RMSE: 0.1399
# Epoch 58/100 | val RMSE: 0.1300
# Epoch 59/100 | val RMSE: 0.1242
# Epoch 60/100 | val RMSE: 0.1232
# Epoch 61/100 | val RMSE: 0.1206
# Epoch 62/100 | val RMSE: 0.1233
# Epoch 63/100 | val RMSE: 0.1271
# Epoch 64/100 | val RMSE: 0.1215
# Epoch 65/100 | val RMSE: 0.1234
# Epoch 66/100 | val RMSE: 0.1218
# Epoch 67/100 | val RMSE: 0.1246
# Epoch 68/100 | val RMSE: 0.1212
# Epoch 69/100 | val RMSE: 0.1214
# Epoch 70/100 | val RMSE: 0.1208
# Epoch 71/100 | val RMSE: 0.1182
# Epoch 72/100 | val RMSE: 0.1205
# Epoch 73/100 | val RMSE: 0.1279
# Epoch 74/100 | val RMSE: 0.1239
# Epoch 75/100 | val RMSE: 0.1193
# Epoch 76/100 | val RMSE: 0.1213
# Epoch 77/100 | val RMSE: 0.1226
# Epoch 78/100 | val RMSE: 0.1388
# Epoch 79/100 | val RMSE: 0.1262
# Epoch 80/100 | val RMSE: 0.1932
# Epoch 81/100 | val RMSE: 0.2528
# Epoch 82/100 | val RMSE: 0.1279
# Epoch 83/100 | val RMSE: 0.1427
# Epoch 84/100 | val RMSE: 0.2736
# Epoch 85/100 | val RMSE: 0.2004
# Epoch 86/100 | val RMSE: 0.2676
# Epoch 87/100 | val RMSE: 0.2703
# Epoch 88/100 | val RMSE: nan
# Epoch 89/100 | val RMSE: nan
# Epoch 90/100 | val RMSE: nan
# Epoch 91/100 | val RMSE: nan
# Epoch 92/100 | val RMSE: nan
# Epoch 93/100 | val RMSE: nan
# Epoch 94/100 | val RMSE: nan
# Epoch 95/100 | val RMSE: nan
# Epoch 96/100 | val RMSE: nan
# Epoch 97/100 | val RMSE: nan
# Epoch 98/100 | val RMSE: nan
# Epoch 99/100 | val RMSE: nan
# Epoch 100/100 | val RMSE: nan
# Fold 1 CENTERED  RMSE 0.4940 | MAE 0.0321 | R² 0.8275 | RMAE 0.3873
# Fold 1 RAW  RMSE 2082412.6341 | MAE 135164.6630 | R² 0.8275 | RMAE 0.3873
# === FOLD 2/8 ===
# Model compiled with torch.compile(mode='max-autotune')
# Using fused AdamW
# Start epoch train for fold 2
# Epoch 01/100 | val RMSE: 0.2219
# Epoch 02/100 | val RMSE: 0.1773
# Epoch 03/100 | val RMSE: 0.1647
# Epoch 04/100 | val RMSE: 0.1594
# Epoch 05/100 | val RMSE: 0.1565
# Epoch 06/100 | val RMSE: 0.1549
# Epoch 07/100 | val RMSE: 0.1570
# Epoch 08/100 | val RMSE: 0.1490
# Epoch 09/100 | val RMSE: 0.1533
# Epoch 10/100 | val RMSE: 0.1584
# Epoch 11/100 | val RMSE: 0.1511
# Epoch 12/100 | val RMSE: 0.1701
# Epoch 13/100 | val RMSE: 0.1909
# Epoch 14/100 | val RMSE: 0.1921
# Epoch 15/100 | val RMSE: 0.1582
# Epoch 16/100 | val RMSE: 0.1801
# Epoch 17/100 | val RMSE: 0.1627
# Epoch 18/100 | val RMSE: 0.1541
# Epoch 19/100 | val RMSE: 0.1572
# Epoch 20/100 | val RMSE: 0.1581
# Epoch 21/100 | val RMSE: 0.1587
# Epoch 22/100 | val RMSE: 0.1491
# Epoch 23/100 | val RMSE: 0.1434
# Epoch 24/100 | val RMSE: 0.1530
# Epoch 25/100 | val RMSE: 0.1514
# Epoch 26/100 | val RMSE: 0.1496
# Epoch 27/100 | val RMSE: 0.1570
# Epoch 28/100 | val RMSE: 0.1385
# Epoch 29/100 | val RMSE: nan
# Epoch 30/100 | val RMSE: nan
# Epoch 31/100 | val RMSE: nan
# Epoch 32/100 | val RMSE: nan
# Epoch 33/100 | val RMSE: nan
# Epoch 34/100 | val RMSE: nan
# Epoch 35/100 | val RMSE: nan
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 36/100 | val RMSE: inf
# Epoch 37/100 | val RMSE: nan
# Epoch 38/100 | val RMSE: nan
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 39/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 40/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 41/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 42/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 43/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 44/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 45/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 46/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 47/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 48/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 49/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 50/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 51/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 52/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 53/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 54/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 55/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 56/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 57/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 58/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 59/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 60/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 61/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 62/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 63/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 64/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 65/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 66/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 67/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 68/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 69/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 70/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 71/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 72/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 73/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 74/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 75/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 76/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 77/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 78/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 79/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 80/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 81/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 82/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 83/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 84/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 85/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 86/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 87/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 88/100 | val RMSE: inf
# Epoch 89/100 | val RMSE: nan
# Epoch 90/100 | val RMSE: nan
# Epoch 91/100 | val RMSE: nan
# Epoch 92/100 | val RMSE: nan
# Epoch 93/100 | val RMSE: nan
# Epoch 94/100 | val RMSE: nan
# Epoch 95/100 | val RMSE: nan
# Epoch 96/100 | val RMSE: nan
# Epoch 97/100 | val RMSE: nan
# Epoch 98/100 | val RMSE: nan
# Epoch 99/100 | val RMSE: nan
# Epoch 100/100 | val RMSE: nan
# Fold 2 CENTERED  RMSE 0.4529 | MAE 0.0479 | R² 0.8351 | RMAE 0.5942
# Fold 2 RAW  RMSE 1909156.9352 | MAE 201938.0424 | R² 0.8351 | RMAE 0.5942
# === FOLD 3/8 ===
# Model compiled with torch.compile(mode='max-autotune')
# Using fused AdamW
# Start epoch train for fold 3
# Epoch 01/100 | val RMSE: 0.2275
# Epoch 02/100 | val RMSE: 0.1754
# Epoch 03/100 | val RMSE: 0.1632
# Epoch 04/100 | val RMSE: 0.1536
# Epoch 05/100 | val RMSE: 0.1517
# Epoch 06/100 | val RMSE: 0.1492
# Epoch 07/100 | val RMSE: 0.1469
# Epoch 08/100 | val RMSE: 0.1438
# Epoch 09/100 | val RMSE: 0.1481
# Epoch 10/100 | val RMSE: 0.1471
# Epoch 11/100 | val RMSE: 0.1591
# Epoch 12/100 | val RMSE: 0.1772
# Epoch 13/100 | val RMSE: 0.1799
# Epoch 14/100 | val RMSE: 0.1765
# Epoch 15/100 | val RMSE: 0.1779
# Epoch 16/100 | val RMSE: 0.1841
# Epoch 17/100 | val RMSE: 0.2117
# Epoch 18/100 | val RMSE: 0.1817
# Epoch 19/100 | val RMSE: 0.1662
# Epoch 20/100 | val RMSE: 0.1630
# Epoch 21/100 | val RMSE: 0.1424
# Epoch 22/100 | val RMSE: 0.1526
# Epoch 23/100 | val RMSE: 0.1485
# Epoch 24/100 | val RMSE: 0.1478
# Epoch 25/100 | val RMSE: 0.1439
# Epoch 26/100 | val RMSE: 0.1507
# Epoch 27/100 | val RMSE: 0.1390
# Epoch 28/100 | val RMSE: 0.1366
# Epoch 29/100 | val RMSE: 0.1314
# Epoch 30/100 | val RMSE: 0.1308
# Epoch 31/100 | val RMSE: 0.1257
# Epoch 32/100 | val RMSE: 0.1217
# Epoch 33/100 | val RMSE: 0.1275
# Epoch 34/100 | val RMSE: 0.1271
# Epoch 35/100 | val RMSE: 0.1419
# Epoch 36/100 | val RMSE: 0.1361
# Epoch 37/100 | val RMSE: 0.1269
# Epoch 38/100 | val RMSE: 0.1301
# Epoch 39/100 | val RMSE: 0.1355
# Epoch 40/100 | val RMSE: 0.1378
# Epoch 41/100 | val RMSE: 0.1346
# Epoch 42/100 | val RMSE: 0.1372
# Epoch 43/100 | val RMSE: 0.1264
# Epoch 44/100 | val RMSE: 0.1376
# Epoch 45/100 | val RMSE: nan
# Epoch 46/100 | val RMSE: nan
# Epoch 47/100 | val RMSE: 0.1508
# Epoch 48/100 | val RMSE: 0.1647
# Epoch 49/100 | val RMSE: nan
# Epoch 50/100 | val RMSE: nan
# Epoch 51/100 | val RMSE: nan
# Epoch 52/100 | val RMSE: nan
# Epoch 53/100 | val RMSE: nan
# Epoch 54/100 | val RMSE: nan
# Epoch 55/100 | val RMSE: nan
# Epoch 56/100 | val RMSE: nan
# Epoch 57/100 | val RMSE: nan
# Epoch 58/100 | val RMSE: nan
# Epoch 59/100 | val RMSE: nan
# Epoch 60/100 | val RMSE: nan
# Epoch 61/100 | val RMSE: nan
# Epoch 62/100 | val RMSE: nan
# Epoch 63/100 | val RMSE: nan
# Epoch 64/100 | val RMSE: nan
# Epoch 65/100 | val RMSE: nan
# Epoch 66/100 | val RMSE: nan
# Epoch 67/100 | val RMSE: nan
# Epoch 68/100 | val RMSE: nan
# Epoch 69/100 | val RMSE: nan
# Epoch 70/100 | val RMSE: nan
# Epoch 71/100 | val RMSE: nan
# Epoch 72/100 | val RMSE: nan
# Epoch 73/100 | val RMSE: nan
# Epoch 74/100 | val RMSE: nan
# Epoch 75/100 | val RMSE: nan
# Epoch 76/100 | val RMSE: nan
# Epoch 77/100 | val RMSE: nan
# Epoch 78/100 | val RMSE: nan
# Epoch 79/100 | val RMSE: nan
# Epoch 80/100 | val RMSE: nan
# Epoch 81/100 | val RMSE: nan
# Epoch 82/100 | val RMSE: nan
# Epoch 83/100 | val RMSE: nan
# Epoch 84/100 | val RMSE: nan
# Epoch 85/100 | val RMSE: nan
# Epoch 86/100 | val RMSE: nan
# Epoch 87/100 | val RMSE: nan
# Epoch 88/100 | val RMSE: nan
# Epoch 89/100 | val RMSE: nan
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 90/100 | val RMSE: inf
# Epoch 91/100 | val RMSE: nan
# Epoch 92/100 | val RMSE: nan
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 93/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 94/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 95/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 96/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 97/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 98/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 99/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 100/100 | val RMSE: inf
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/cudagraph_trees.py:2450: UserWarning: Unable to hit fast path of CUDAGraphs because of pending, uninvoked backwards. Consider running with torch.no_grad() or using torch.compiler.cudagraph_mark_step_begin() before each model invocation
#   warnings.warn(
# Fold 3 CENTERED  RMSE 0.3116 | MAE 0.0391 | R² 0.9225 | RMAE 0.4791
# Fold 3 RAW  RMSE 1313756.0568 | MAE 164937.1335 | R² 0.9225 | RMAE 0.4791
# === FOLD 4/8 ===
# Model compiled with torch.compile(mode='max-autotune')
# Using fused AdamW
# Start epoch train for fold 4
# Epoch 01/100 | val RMSE: 0.2095
# Epoch 02/100 | val RMSE: 0.1614
# Epoch 03/100 | val RMSE: 0.1517
# Epoch 04/100 | val RMSE: 0.1448
# Epoch 05/100 | val RMSE: 0.1422
# Epoch 06/100 | val RMSE: 0.1404
# Epoch 07/100 | val RMSE: 0.1383
# Epoch 08/100 | val RMSE: 0.1382
# Epoch 09/100 | val RMSE: 0.1396
# Epoch 10/100 | val RMSE: 0.1429
# Epoch 11/100 | val RMSE: 0.1373
# Epoch 12/100 | val RMSE: 0.1346
# Epoch 13/100 | val RMSE: 0.1350
# Epoch 14/100 | val RMSE: 0.1404
# Epoch 15/100 | val RMSE: 0.1415
# Epoch 16/100 | val RMSE: 0.1453
# Epoch 17/100 | val RMSE: 0.1360
# Epoch 18/100 | val RMSE: 0.1405
# Epoch 19/100 | val RMSE: 0.1347
# Epoch 20/100 | val RMSE: 0.1407
# Epoch 21/100 | val RMSE: 0.1343
# Epoch 22/100 | val RMSE: 0.1365
# Epoch 23/100 | val RMSE: 0.1380
# Epoch 24/100 | val RMSE: 0.1328
# Epoch 25/100 | val RMSE: 0.1396
# Epoch 26/100 | val RMSE: 0.1425
# Epoch 27/100 | val RMSE: 0.1281
# Epoch 28/100 | val RMSE: 0.1212
# Epoch 29/100 | val RMSE: 0.1354
# Epoch 30/100 | val RMSE: 0.1272
# Epoch 31/100 | val RMSE: 0.1225
# Epoch 32/100 | val RMSE: 0.1241
# Epoch 33/100 | val RMSE: 0.1227
# Epoch 34/100 | val RMSE: 0.1225
# Epoch 35/100 | val RMSE: 0.1238
# Epoch 36/100 | val RMSE: 0.1208
# Epoch 37/100 | val RMSE: 0.1192
# Epoch 38/100 | val RMSE: 0.1134
# Epoch 39/100 | val RMSE: 0.1188
# Epoch 40/100 | val RMSE: 0.1199
# Epoch 41/100 | val RMSE: 0.1141
# Epoch 42/100 | val RMSE: 0.1140
# Epoch 43/100 | val RMSE: 0.1126
# Epoch 44/100 | val RMSE: 0.1193
# Epoch 45/100 | val RMSE: 0.1122
# Epoch 46/100 | val RMSE: 0.1119
# Epoch 47/100 | val RMSE: 0.1161
# Epoch 48/100 | val RMSE: 0.1161
# Epoch 49/100 | val RMSE: 0.1181
# Epoch 50/100 | val RMSE: 0.1152
# Epoch 51/100 | val RMSE: 0.1149
# Epoch 52/100 | val RMSE: 0.1173
# Epoch 53/100 | val RMSE: 0.1181
# Epoch 54/100 | val RMSE: 0.1116
# Epoch 55/100 | val RMSE: 0.1120
# Epoch 56/100 | val RMSE: 0.1110
# Epoch 57/100 | val RMSE: 0.1093
# Epoch 58/100 | val RMSE: 0.1127
# Epoch 59/100 | val RMSE: 0.1077
# Epoch 60/100 | val RMSE: 0.1088
# Epoch 61/100 | val RMSE: 0.1066
# Epoch 62/100 | val RMSE: 0.1072
# Epoch 63/100 | val RMSE: 0.1084
# Epoch 64/100 | val RMSE: 0.1061
# Epoch 65/100 | val RMSE: 0.1049
# Epoch 66/100 | val RMSE: 0.1154
# Epoch 67/100 | val RMSE: 0.1106
# Epoch 68/100 | val RMSE: 0.1073
# Epoch 69/100 | val RMSE: 0.1052
# Epoch 70/100 | val RMSE: 0.1054
# Epoch 71/100 | val RMSE: 0.1065
# Epoch 72/100 | val RMSE: 0.1053
# Epoch 73/100 | val RMSE: 0.1051
# Epoch 74/100 | val RMSE: 0.1103
# Epoch 75/100 | val RMSE: 0.1161
# Epoch 76/100 | val RMSE: 0.1031
# Epoch 77/100 | val RMSE: 0.1045
# Epoch 78/100 | val RMSE: nan
# Epoch 79/100 | val RMSE: nan
# Epoch 80/100 | val RMSE: nan
# Epoch 81/100 | val RMSE: nan
# Epoch 82/100 | val RMSE: nan
# Epoch 83/100 | val RMSE: 0.2365
# Epoch 84/100 | val RMSE: nan
# Epoch 85/100 | val RMSE: nan
# Epoch 86/100 | val RMSE: nan
# Epoch 87/100 | val RMSE: nan
# Epoch 88/100 | val RMSE: nan
# Epoch 89/100 | val RMSE: nan
# Epoch 90/100 | val RMSE: nan
# Epoch 91/100 | val RMSE: nan
# Epoch 92/100 | val RMSE: 0.1612
# Epoch 93/100 | val RMSE: 0.1458
# Epoch 94/100 | val RMSE: 0.1421
# Epoch 95/100 | val RMSE: 0.2711
# Epoch 96/100 | val RMSE: 0.1612
# Epoch 97/100 | val RMSE: 0.1578
# Epoch 98/100 | val RMSE: 0.1275
# Epoch 99/100 | val RMSE: 0.1040
# Epoch 100/100 | val RMSE: 0.1018
# Fold 4 CENTERED  RMSE 0.2106 | MAE 0.0331 | R² 0.9538 | RMAE 0.4379
# Fold 4 RAW  RMSE 887926.5962 | MAE 139412.8461 | R² 0.9538 | RMAE 0.4379
# === FOLD 5/8 ===
# Model compiled with torch.compile(mode='max-autotune')
# Using fused AdamW
# Start epoch train for fold 5
# Epoch 01/100 | val RMSE: 0.2085
# Epoch 02/100 | val RMSE: 0.1682
# Epoch 03/100 | val RMSE: 0.1543
# Epoch 04/100 | val RMSE: 0.1477
# Epoch 05/100 | val RMSE: 0.1453
# Epoch 06/100 | val RMSE: 0.1435
# Epoch 07/100 | val RMSE: 0.1365
# Epoch 08/100 | val RMSE: 0.1416
# Epoch 09/100 | val RMSE: 0.1380
# Epoch 10/100 | val RMSE: 0.1384
# Epoch 11/100 | val RMSE: 0.1326
# Epoch 12/100 | val RMSE: 0.1397
# Epoch 13/100 | val RMSE: 0.1343
# Epoch 14/100 | val RMSE: 0.1449
# Epoch 15/100 | val RMSE: 0.1673
# Epoch 16/100 | val RMSE: 0.1592
# Epoch 17/100 | val RMSE: 0.1458
# Epoch 18/100 | val RMSE: 0.1420
# Epoch 19/100 | val RMSE: 0.1468
# Epoch 20/100 | val RMSE: 0.1473
# Epoch 21/100 | val RMSE: 0.1334
# Epoch 22/100 | val RMSE: 0.1407
# Epoch 23/100 | val RMSE: 0.1313
# Epoch 24/100 | val RMSE: 0.1365
# Epoch 25/100 | val RMSE: 0.1456
# Epoch 26/100 | val RMSE: 0.1291
# Epoch 27/100 | val RMSE: 0.1355
# Epoch 28/100 | val RMSE: 0.1287
# Epoch 29/100 | val RMSE: 0.1338
# Epoch 30/100 | val RMSE: 0.1310
# Epoch 31/100 | val RMSE: 0.1249
# Epoch 32/100 | val RMSE: 0.1195
# Epoch 33/100 | val RMSE: 0.1200
# Epoch 34/100 | val RMSE: 0.1215
# Epoch 35/100 | val RMSE: 0.1220
# Epoch 36/100 | val RMSE: 0.1222
# Epoch 37/100 | val RMSE: 0.1166
# Epoch 38/100 | val RMSE: 0.1183
# Epoch 39/100 | val RMSE: 0.1247
# Epoch 40/100 | val RMSE: 0.1170
# Epoch 41/100 | val RMSE: 0.1154
# Epoch 42/100 | val RMSE: 0.1162
# Epoch 43/100 | val RMSE: 0.1163
# Epoch 44/100 | val RMSE: nan
# Epoch 45/100 | val RMSE: nan
# Epoch 46/100 | val RMSE: nan
# Epoch 47/100 | val RMSE: nan
# Epoch 48/100 | val RMSE: nan
# Epoch 49/100 | val RMSE: nan
# Epoch 50/100 | val RMSE: nan
# Epoch 51/100 | val RMSE: nan
# Epoch 52/100 | val RMSE: nan
# Epoch 53/100 | val RMSE: nan
# Epoch 54/100 | val RMSE: 0.1143
# Epoch 55/100 | val RMSE: 0.1146
# Epoch 56/100 | val RMSE: 0.1170
# Epoch 57/100 | val RMSE: 0.1179
# Epoch 58/100 | val RMSE: 0.1230
# Epoch 59/100 | val RMSE: 0.1107
# Epoch 60/100 | val RMSE: nan
# Epoch 61/100 | val RMSE: nan
# Epoch 62/100 | val RMSE: 0.1087
# Epoch 63/100 | val RMSE: nan
# Epoch 64/100 | val RMSE: nan
# Epoch 65/100 | val RMSE: nan
# Epoch 66/100 | val RMSE: nan
# Epoch 67/100 | val RMSE: nan
# Epoch 68/100 | val RMSE: nan
# Epoch 69/100 | val RMSE: nan
# Epoch 70/100 | val RMSE: nan
# Epoch 71/100 | val RMSE: nan
# Epoch 72/100 | val RMSE: nan
# Epoch 73/100 | val RMSE: nan
# Epoch 74/100 | val RMSE: nan
# Epoch 75/100 | val RMSE: nan
# Epoch 76/100 | val RMSE: nan
# Epoch 77/100 | val RMSE: nan
# Epoch 78/100 | val RMSE: 0.1655
# Epoch 79/100 | val RMSE: 0.1633
# Epoch 80/100 | val RMSE: 0.1665
# Epoch 81/100 | val RMSE: 0.1722
# Epoch 82/100 | val RMSE: 0.1774
# Epoch 83/100 | val RMSE: 0.1742
# Epoch 84/100 | val RMSE: nan
# Epoch 85/100 | val RMSE: nan
# Epoch 86/100 | val RMSE: nan
# Epoch 87/100 | val RMSE: nan
# Epoch 88/100 | val RMSE: nan
# Epoch 89/100 | val RMSE: nan
# Epoch 90/100 | val RMSE: nan
# Epoch 91/100 | val RMSE: nan
# Epoch 92/100 | val RMSE: nan
# Epoch 93/100 | val RMSE: nan
# Epoch 94/100 | val RMSE: nan
# Epoch 95/100 | val RMSE: nan
# Epoch 96/100 | val RMSE: nan
# Epoch 97/100 | val RMSE: nan
# Epoch 98/100 | val RMSE: nan
# Epoch 99/100 | val RMSE: nan
# Epoch 100/100 | val RMSE: nan
# Fold 5 CENTERED  RMSE 0.2550 | MAE 0.0324 | R² 0.9347 | RMAE 0.4318
# Fold 5 RAW  RMSE 1074966.9412 | MAE 136694.6882 | R² 0.9347 | RMAE 0.4318
# === FOLD 6/8 ===
# Model compiled with torch.compile(mode='max-autotune')
# Using fused AdamW
# Start epoch train for fold 6
# Epoch 01/100 | val RMSE: 0.2211
# Epoch 02/100 | val RMSE: 0.1746
# Epoch 03/100 | val RMSE: 0.1636
# Epoch 04/100 | val RMSE: 0.1580
# Epoch 05/100 | val RMSE: 0.1512
# Epoch 06/100 | val RMSE: 0.1495
# Epoch 07/100 | val RMSE: 0.1544
# Epoch 08/100 | val RMSE: 0.1468
# Epoch 09/100 | val RMSE: 0.1424
# Epoch 10/100 | val RMSE: 0.1512
# Epoch 11/100 | val RMSE: 0.1480
# Epoch 12/100 | val RMSE: 0.1414
# Epoch 13/100 | val RMSE: 0.1480
# Epoch 14/100 | val RMSE: 0.1469
# Epoch 15/100 | val RMSE: 0.1518
# Epoch 16/100 | val RMSE: 0.1652
# Epoch 17/100 | val RMSE: 0.1612
# Epoch 18/100 | val RMSE: 0.1494
# Epoch 19/100 | val RMSE: 0.1431
# Epoch 20/100 | val RMSE: 0.1544
# Epoch 21/100 | val RMSE: 0.1499
# Epoch 22/100 | val RMSE: 0.1472
# Epoch 23/100 | val RMSE: 0.1374
# Epoch 24/100 | val RMSE: 0.1338
# Epoch 25/100 | val RMSE: 0.1603
# Epoch 26/100 | val RMSE: 0.1462
# Epoch 27/100 | val RMSE: 0.1355
# Epoch 28/100 | val RMSE: 0.1345
# Epoch 29/100 | val RMSE: 0.1350
# Epoch 30/100 | val RMSE: 0.1364
# Epoch 31/100 | val RMSE: 0.1341
# Epoch 32/100 | val RMSE: 0.1322
# Epoch 33/100 | val RMSE: 0.1315
# Epoch 34/100 | val RMSE: 0.1260
# Epoch 35/100 | val RMSE: 0.1274
# Epoch 36/100 | val RMSE: 0.1314
# Epoch 37/100 | val RMSE: 0.1278
# Epoch 38/100 | val RMSE: 0.1281
# Epoch 39/100 | val RMSE: 0.1354
# Epoch 40/100 | val RMSE: 0.1294
# Epoch 41/100 | val RMSE: nan
# Epoch 42/100 | val RMSE: nan
# Epoch 43/100 | val RMSE: nan
# Epoch 44/100 | val RMSE: nan
# Epoch 45/100 | val RMSE: nan
# Epoch 46/100 | val RMSE: nan
# Epoch 47/100 | val RMSE: nan
# Epoch 48/100 | val RMSE: nan
# Epoch 49/100 | val RMSE: 0.1212
# Epoch 50/100 | val RMSE: nan
# Epoch 51/100 | val RMSE: nan
# Epoch 52/100 | val RMSE: nan
# Epoch 53/100 | val RMSE: 0.1207
# Epoch 54/100 | val RMSE: 0.1178
# Epoch 55/100 | val RMSE: nan
# Epoch 56/100 | val RMSE: nan
# Epoch 57/100 | val RMSE: nan
# Epoch 58/100 | val RMSE: 0.1188
# Epoch 59/100 | val RMSE: 0.1161
# Epoch 60/100 | val RMSE: 0.1181
# Epoch 61/100 | val RMSE: 0.1251
# Epoch 62/100 | val RMSE: 0.1201
# Epoch 63/100 | val RMSE: 0.1308
# Epoch 64/100 | val RMSE: 0.1488
# Epoch 65/100 | val RMSE: 0.1546
# Epoch 66/100 | val RMSE: 0.1386
# Epoch 67/100 | val RMSE: 0.1188
# Epoch 68/100 | val RMSE: 0.1270
# Epoch 69/100 | val RMSE: 0.1243
# Epoch 70/100 | val RMSE: 0.1282
# Epoch 71/100 | val RMSE: 0.1477
# Epoch 72/100 | val RMSE: 0.1535
# Epoch 73/100 | val RMSE: 0.1464
# Epoch 74/100 | val RMSE: 0.1509
# Epoch 75/100 | val RMSE: 0.1485
# Epoch 76/100 | val RMSE: 0.1406
# Epoch 77/100 | val RMSE: 0.1612
# Epoch 78/100 | val RMSE: 0.1904
# Epoch 79/100 | val RMSE: 0.1623
# Epoch 80/100 | val RMSE: 0.1664
# Epoch 81/100 | val RMSE: 0.1939
# Epoch 82/100 | val RMSE: nan
# Epoch 83/100 | val RMSE: nan
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 84/100 | val RMSE: inf
# Epoch 85/100 | val RMSE: nan
# Epoch 86/100 | val RMSE: nan
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 87/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 88/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 89/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 90/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 91/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 92/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 93/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 94/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 95/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 96/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 97/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 98/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 99/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 100/100 | val RMSE: inf
# Fold 6 CENTERED  RMSE 0.3039 | MAE 0.0295 | R² 0.9249 | RMAE 0.3668
# Fold 6 RAW  RMSE 1281172.8819 | MAE 124333.0469 | R² 0.9249 | RMAE 0.3668
# === FOLD 7/8 ===
# Model compiled with torch.compile(mode='max-autotune')
# Using fused AdamW
# Start epoch train for fold 7
# Epoch 01/100 | val RMSE: 0.2201
# Epoch 02/100 | val RMSE: 0.1697
# Epoch 03/100 | val RMSE: 0.1609
# Epoch 04/100 | val RMSE: 0.1512
# Epoch 05/100 | val RMSE: 0.1479
# Epoch 06/100 | val RMSE: 0.1493
# Epoch 07/100 | val RMSE: 0.1474
# Epoch 08/100 | val RMSE: 0.1462
# Epoch 09/100 | val RMSE: 0.1460
# Epoch 10/100 | val RMSE: 0.1490
# Epoch 11/100 | val RMSE: 0.1464
# Epoch 12/100 | val RMSE: 0.1728
# Epoch 13/100 | val RMSE: 0.1612
# Epoch 14/100 | val RMSE: 0.1837
# Epoch 15/100 | val RMSE: 0.1651
# Epoch 16/100 | val RMSE: 0.1512
# Epoch 17/100 | val RMSE: 0.1536
# Epoch 18/100 | val RMSE: 0.1658
# Epoch 19/100 | val RMSE: 0.1510
# Epoch 20/100 | val RMSE: 0.1634
# Epoch 21/100 | val RMSE: 0.1506
# Epoch 22/100 | val RMSE: 0.1454
# Epoch 23/100 | val RMSE: 0.1308
# Epoch 24/100 | val RMSE: 0.1306
# Epoch 25/100 | val RMSE: 0.1454
# Epoch 26/100 | val RMSE: 0.1332
# Epoch 27/100 | val RMSE: 0.1375
# Epoch 28/100 | val RMSE: 0.1276
# Epoch 29/100 | val RMSE: 0.1329
# Epoch 30/100 | val RMSE: 0.1312
# Epoch 31/100 | val RMSE: 0.1251
# Epoch 32/100 | val RMSE: 0.1301
# Epoch 33/100 | val RMSE: 0.1295
# Epoch 34/100 | val RMSE: 0.1253
# Epoch 35/100 | val RMSE: 0.1208
# Epoch 36/100 | val RMSE: 0.1227
# Epoch 37/100 | val RMSE: 0.1217
# Epoch 38/100 | val RMSE: nan
# Epoch 39/100 | val RMSE: nan
# Epoch 40/100 | val RMSE: nan
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 41/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 42/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 43/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 44/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 45/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 46/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 47/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 48/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 49/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 50/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 51/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 52/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 53/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 54/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 55/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 56/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 57/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 58/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 59/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 60/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 61/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 62/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 63/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 64/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 65/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 66/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 67/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 68/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 69/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 70/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 71/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 72/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 73/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 74/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 75/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 76/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 77/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 78/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 79/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 80/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 81/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 82/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 83/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 84/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 85/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 86/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 87/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 88/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 89/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 90/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 91/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 92/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 93/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 94/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 95/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 96/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 97/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 98/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 99/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 100/100 | val RMSE: inf
# Fold 7 CENTERED  RMSE 0.3370 | MAE 0.0447 | R² 0.8994 | RMAE 0.5763
# Fold 7 RAW  RMSE 1420742.5083 | MAE 188511.1769 | R² 0.8994 | RMAE 0.5763
# === FOLD 8/8 ===
# Model compiled with torch.compile(mode='max-autotune')
# Using fused AdamW
# Start epoch train for fold 8
# Epoch 01/100 | val RMSE: 0.2195
# Epoch 02/100 | val RMSE: 0.1676
# Epoch 03/100 | val RMSE: 0.1542
# Epoch 04/100 | val RMSE: 0.1484
# Epoch 05/100 | val RMSE: 0.1464
# Epoch 06/100 | val RMSE: 0.1442
# Epoch 07/100 | val RMSE: 0.1378
# Epoch 08/100 | val RMSE: 0.1468
# Epoch 09/100 | val RMSE: 0.1395
# Epoch 10/100 | val RMSE: 0.1369
# Epoch 11/100 | val RMSE: 0.1499
# Epoch 12/100 | val RMSE: 0.1778
# Epoch 13/100 | val RMSE: 0.1585
# Epoch 14/100 | val RMSE: 0.1722
# Epoch 15/100 | val RMSE: 0.1811
# Epoch 16/100 | val RMSE: 0.1668
# Epoch 17/100 | val RMSE: 0.1580
# Epoch 18/100 | val RMSE: 0.1833
# Epoch 19/100 | val RMSE: 0.1633
# Epoch 20/100 | val RMSE: 0.1913
# Epoch 21/100 | val RMSE: 0.1469
# Epoch 22/100 | val RMSE: 0.1341
# Epoch 23/100 | val RMSE: 0.1300
# Epoch 24/100 | val RMSE: 0.1321
# Epoch 25/100 | val RMSE: nan
# Epoch 26/100 | val RMSE: 0.1343
# Epoch 27/100 | val RMSE: 0.1317
# Epoch 28/100 | val RMSE: nan
# Epoch 29/100 | val RMSE: nan
# Epoch 30/100 | val RMSE: nan
# Epoch 31/100 | val RMSE: nan
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 32/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 33/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 34/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 35/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 36/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 37/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 38/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 39/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 40/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 41/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 42/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 43/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 44/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 45/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 46/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 47/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 48/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 49/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 50/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 51/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 52/100 | val RMSE: inf
# Epoch 53/100 | val RMSE: nan
# Epoch 54/100 | val RMSE: nan
# Epoch 55/100 | val RMSE: nan
# Epoch 56/100 | val RMSE: nan
# Epoch 57/100 | val RMSE: nan
# Epoch 58/100 | val RMSE: nan
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 59/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 60/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 61/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 62/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 63/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 64/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 65/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 66/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 67/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 68/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 69/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 70/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 71/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 72/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 73/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 74/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 75/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 76/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 77/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 78/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 79/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 80/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 81/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 82/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 83/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 84/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 85/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 86/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 87/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 88/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 89/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 90/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 91/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 92/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 93/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 94/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 95/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 96/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 97/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 98/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 99/100 | val RMSE: inf
# ⚠️ NaN or Inf detected in y_pred — stopping here!
# Epoch 100/100 | val RMSE: inf
# Fold 8 CENTERED  RMSE 0.2834 | MAE 0.0464 | R² 0.9217 | RMAE 0.5893
# Fold 8 RAW  RMSE 1194824.4002 | MAE 195554.3589 | R² 0.9217 | RMAE 0.5893

# %% [markdown]
# ## Save Model

# %%
torch.save({
  "model_state_dict": best_fold_state,
  "model_hyperparams": {
    "n_features": len(FEATURES),
    "n_dyads": len(dyad_to_idx),
    "n_layers": N_LAYERS,
    "embed_dim": EMBEDDING_SIZE,
    "hidden_size": HIDDEN_SIZE,
    "dropout": DROPOUT,
    "horizon": HORIZON,
    "type": XLSTM_TYPE,
    "layers": XLSTM_LAYERS,
  },
  "dyad_to_idx": dyad_to_idx,
  "feature_names": FEATURES,
}, PATH_TO_FOLDER + SERIAL_NUMBER + ".pt")
print("Saved model to", PATH_TO_FOLDER + SERIAL_NUMBER + ".pt")
# Out:
# Saved model to XLSTM(smsm)-0_0003lr-0_05d-768hs-0_001wd-2048bs-3layers-256es-kfolds8-hp.pt

# %%
def summarize(xs):
  xs = np.asarray(xs, dtype=float)
  n = xs.size
  mean = xs.mean()
  std = xs.std(ddof=1)  # sample std
  se = std / math.sqrt(n)
  try:
    from scipy.stats import t
    tcrit = t.ppf(0.975, df=n - 1)
  except Exception:
    tcrit = 1.96  # normal approx≈
  ci95 = tcrit * se
  return mean, std, ci95

# %%
print("\n=== Cross-fold CENTERED summary ===")
for name in ["MAE", "RMSE", "R2", "RMAE"]:
  mean, std, ci = summarize(metrics_per_fold[name])
  print(f"{name:>5}: {mean:.4f} ± {std:.4f}  (95% CI ±{ci:.4f})")

print("\n=== Cross-fold RAW summary ===")
for name in ["MAE", "RMSE", "R2", "RMAE"]:
  mean, std, ci = summarize(metrics_per_fold_raw[name])
  print(f"{name:>5}: {mean:.4f} ± {std:.4f}  (95% CI ±{ci:.4f})")
# Out:
# === Cross-fold CENTERED summary ===
#   MAE: 0.0381 ± 0.0073  (95% CI ±0.0061)
#  RMSE: 0.3310 ± 0.0964  (95% CI ±0.0806)
#    R2: 0.9025 ± 0.0465  (95% CI ±0.0388)
#  RMAE: 0.4829 ± 0.0923  (95% CI ±0.0772)
#
# === Cross-fold RAW summary ===
#   MAE: 160818.2445 ± 30962.4476  (95% CI ±25885.2539)
#  RMSE: 1395619.8692 ± 406505.1650  (95% CI ±339846.8226)
#    R2: 0.9025 ± 0.0465  (95% CI ±0.0388)
#  RMAE: 0.4829 ± 0.0923  (95% CI ±0.0772)
